# %%
import spacy
import pickle

# %% [markdown]
# ### Load NER model

# %%
model = pickle.load(open("NER.pickle", "rb"))

# %% [markdown]
# ### Text to test the entity_linking model

# %%
text = "Bambang merupakan pemain bola yang menjadi andalan indonesia"
doc = model(text)
for ent in doc.ents:
    print(f"Named entity '{ent.text}' with label '{ent.label_}'")
# Out:
# Named entity 'Bambang' with label 'PERSON'
# Named entity 'pemain bola' with label 'JOB_TITLE'

# %% [markdown]
# ### Create function to load initial Knowledge Base data from csv

# %%
import csv
from pathlib import Path
def load_entities():
    name_loc = Path.cwd() / "dict_name.csv"
    desc_loc = Path.cwd()/"dict_desc.csv"
    names = dict()
    description = dict()
    with name_loc.open("r", encoding="utf8") as csvname:
        namereader = csv.reader(csvname, delimiter=",")
        for row in namereader:
            qid = row[0]
            name = row[1]
            names[qid] = name
    
    with desc_loc.open("r", encoding="utf8") as csvdesc:
        descreader = csv.reader(csvdesc, delimiter=",")
        for row in descreader:
            qid = row[0]
            desc = row[1]
            description[qid] = desc
    return names,description

# %% [markdown]
# ### Define name dictionary and description dict for wikidata

# %%
name_dict, desc_dict = load_entities()
for QID in name_dict.keys():
    print(f"{QID}, name={name_dict[QID]}, desc={desc_dict[QID]}")
# Out:
# Q221310, name=Anggun C. Sasmi, desc=penyanyi-penulis lagu Indonesia-Prancis
# Q1362169, name=Agnez Mo, desc=penyanyi dan artis Internasional
# Q76127, name=Soekarno, desc=Presiden pertama Republik Indonesia
# Q3318231, name=Joko Widodo, desc=presiden ke-7 Indonesia
# Q44819, name=Soeharto, desc=Presiden ke-2 Republik Indonesia dari 1967 hingga 1998
# Q76179, name=Megawati Soekarnoputri, desc=Presiden ke-5 dan Wakil Presiden ke-8 Republik Indonesia
# Q57405, name=Susilo Bambang Yudhoyono, desc=Presiden ke-6 Republik Indonesia dari 2004 sampai 2014
# Q189488, name=Willem Einthoven, desc=dosen
# Q76167, name=Abdurrahman Wahid, desc=Presiden ke-4 Republik Indonesia dari 1999 hingga 2001
# Q76156, name=Bacharuddin Jusuf Habibie, desc=presiden ke-3 dan wakil presiden ke-7 Indonesia
# Q326935, name=Pramoedya Ananta Toer, desc=penulis Indonesia
# Q29050, name=Mohammad Hatta, desc=Wakil Presiden Republik Indonesia ke-1
# Q42297483, name=Hary Gunarto, desc=ilmuwan Jepang
# Q315689, name=Andrés Scotti, desc=Uruguayan footballer
# Q232400, name=Hella S. Haasse, desc=Dutch writer (1918-2011)
# Q981543, name=Rio Haryanto, desc=pembalap mobil Indonesia
# Q559017, name=Chairil Anwar, desc=Pahlawan Revolusi Kemerdekaan
# Q28481203, name=Muammar Z.A., desc=Qari' ternama Nasional & Internasional
# Q76354, name=Muhammad Jusuf Kalla, desc=Wakil Presiden Indonesia ke-10 dan ke-12
# Q3391654, name=Jessica Iskandar, desc=pemeran perempuan asal Indonesia
# Q660145, name=Taufik Hidayat, desc=pemain bulu tangkis berkebangsaan Indonesia
# Q1373764, name=Kartini, desc=pahlawan nasional Indonesia
# Q606577, name=Olga Syahputra, desc=pemeran laki-laki asal Indonesia
# Q66115, name=Lil Dagover, desc=German actress (1887-1980)
# Q3981632, name=Amir Hamzah, desc=Pahlawan Revolusi Kemerdekaan
# Q558761, name=Markis Kido, desc=Pemain Bulutangkis Indonesia
# Q369416, name=Jan Toorop, desc=Dutch-Indonesian painter (1858–1928)
# Q240527, name=Laura Gemser, desc=Dutch-based actress of Indonesian descent
# Q76297, name=Adam Malik, desc=Wakil Presiden Republik Indonesia ke-3
# Q464589, name=Susi Susanti, desc=pemain bulu tangkis Indonesia
# Q468400, name=Alan Budikusuma, desc=Pemain bulu tangkis Indonesia
# Q468531, name=Anneke Grönloh, desc=Dutch singer (1942-2018)
# Q468407, name=Julius Darmaatmadja, desc=Kardinal Katolik Roma
# Q3177708, name=Sri Mulyani Indrawati, desc=ekonom Indonesia
# Q554549, name=Eko Yuli Irawan, desc=Indonesian weightlifter
# Q558979, name=D. N. Aidit, desc=Politisi Indonesia
# Q468506, name=Greysia Polii, desc=pemain bulu tangkis asal Indonesia
# Q2350460, name=Iko Uwais, desc=pemeran laki-laki, pemeran pengganti, dan olahragawan pencak silat berkebangsaan Indonesia
# Q1375979, name=Raden Saleh, desc=pelukis Indonesia
# Q26710852, name=Mbah Gotho, desc=Orang tertua di Indonesia
# Q17410409, name=Emil Audero, desc=Italian footballer
# Q4264834, name=Amara, desc=penyanyi dan pemeran perempuan asal Indonesia
# Q12033409, name=Fatin Shidqia, desc=penyanyi Indonesia
# Q2107268, name=Prabowo Subianto, desc=Menteri Pertahanan Indonesia ke-26
# Q5388188, name=Erick Thohir, desc=Menteri BUMN ke-9
# Q58961, name=Willem Luyten, desc=Dutch-American astronomer (1899–1994)
# Q975434, name=Bambang Pamungkas, desc=pesepak bola Indonesia
# Q561701, name=Hendra Setiawan, desc=Pemain bulu tangkis Indonesia
# Q291116, name=Sandra Reemer, desc=penyanyi Belanda
# Q464583, name=Yayuk Basuki, desc=petenis asal Indonesia
# Q12497177, name=Ma'ruf Amin, desc=Ulama Islam dan Wakil Presiden Indonesia ke-13
# Q538107, name=Ignatius Suharyo, desc=Kardinal Katolik Roma
# Q256628, name=Xenia Stad-de Jong, desc=Dutch sprinter
# Q18342668, name=Retno Marsudi, desc=Politikus dan diplomat asal Indonesia
# Q813518, name=Beb Bakhuys, desc=Dutch footballer and manager (1909-1982)
# Q367575, name=Adriaan Daniel Fokker, desc=dosen
# Q1815982, name=Ki Hadjar Dewantara, desc=pahlawan nasional Indonesia
# Q464630, name=Liliyana Natsir, desc=pemain bulu tangkis asal Indonesia
# Q317291, name=Abdul Haris Nasution, desc=pahlawan nasional Indonesia
# Q253983, name=Maria Kristin Yulianti, desc=pemain badminton asal Indonesia
# Q1401053, name=Abdoel Moeis, desc=Pahlawan Revolusi Kemerdekaan
# Q561682, name=Tan Malaka, desc=pahlawan nasional Indonesia
# Q3701615, name=Basuki Tjahaja Purnama, desc=Mantan Gubernur DKI Jakarta, Wakil Gubernur DKI Jakarta
# Q50797, name=Taco, desc=Dutch singer
# Q265153, name=Mia Audina, desc=pemain bulu tangkis asal Indonesia
# Q3347367, name=Julia Perez, desc=pemeran perempuan asal Indonesia
# Q2470857, name=Sutan Syahrir, desc=pahlawan nasional Indonesia
# Q3459336, name=Joe Taslim, desc=aktor, model dan penyanyi Indonesia
# Q118629, name=Agus Salim, desc=pahlawan nasional Indonesia
# Q76362, name=Boediono, desc=Wakil Presiden Indonesia ke-11
# Q584761, name=Angelique Widjaja, desc=petenis profesional asal Indonesia.
# Q22958340, name=Sri Wahyuni Agustiani, desc=Atlet Angkat Besi
# Q27267034, name=Rich Brian, desc=Rapper Indonesia
# Q658330, name=Arie de Jong, desc=volapükist from the Netherlands (1865-1957)
# Q732135, name=Chrisye, desc=penyanyi dan penulis lagu Indonesia
# Q104560457, name=Defri Juliant, desc=penyanyi Indonesia
# Q3363540, name=Parameswara, desc=Sumatran man who built the Malacca Sultanate
# Q506333, name=Tontowi Ahmad, desc=pemain bulu tangkis Indonesia
# Q712489, name=Henk Badings, desc=Dutch composer born in Java
# Q1318953, name=Ayu Utami, desc=aktivis jurnalis, sastrawan, dan penulis berkebangsaan Indonesia.
# Q16724324, name=Anthony Sinisuka Ginting, desc=pemain bulu tangkis Indonesia
# Q76227, name=Hamengkubuwana IX, desc=pahlawan nasional Indonesia
# Q2183970, name=Cut Nyak Dhien, desc=pahlawan nasional Indonesia
# Q468519, name=Fatmawati, desc=pahlawan nasional Indonesia
# Q571426, name=Johan Hendrik Caspar Kern, desc=Dutch linguist and orientalist
# Q2669342, name=Hamengkubuwana X, desc=sultan ke-10 Yogyakarta dan Gubernur Daerah Istimewa Yogyakarta ke-3
# Q97193011, name=Windy Cantika Aisah, desc=atlet angkat besi asal Indonesia
# Q2321261, name=Eka Kurniawan, desc=Penulis Indonesia
# Q2735641, name=Rhoma Irama, desc=musisi dan pemeran laki-laki asal Indonesia
# Q23723804, name=Apriyani Rahayu, desc=pemain bulu tangkis asal Indonesia
# Q12856730, name=Jung Joon-young, desc=South Korean singer-songwriter
# Q364683, name=Adolph van der Voort van Zijp, desc=Dutch equestrian (1892-1978)
# Q2669326, name=Ali Sastroamidjojo, desc=Pahlawan Revolusi Kemerdekaan
# Q17411488, name=Susi Pudjiastuti, desc=Mantan Menteri Kelautan dan Perikanan RI
# Q640195, name=Ardy Wiranata, desc=Pebulu tangkis Indonesia
# Q1144049, name=Wage Rudolf Soepratman, desc=violinis dan komponis Indonesia
# Q185282, name=Muhammad Ahsan, desc=pemain bulu tangkis asal Indonesia
# Q454488, name=Lien Gisolf, desc=Dutch athlete
# Q2570788, name=Mochtar Lubis, desc=pengarang Indonesia
# Q731979, name=Nova Widianto, desc=badminton player
# Q58290, name=Marty Natalegawa, desc=Menteri Luar Negeri Indonesia ke-17
# Q4131328, name=Rossa, desc=penyanyi Indonesia
# Q290581, name=Xaviera Hollander, desc=Dutch prostitute
# Q731914, name=Sony Dwi Kuncoro, desc=Indonesian badminton player
# Q1392969, name=I Gusti Ngurah Rai, desc=pahlawan nasional Indonesia
# Q4263230, name=Anies Baswedan, desc=Gubernur Daerah Khusus Ibukota Jakarta dari 2017 sampai sekarang
# Q2327343, name=Mohammad Natsir, desc=pahlawan nasional Indonesia
# Q1810083, name=Amir Sjarifoeddin, desc=pahlawan nasional Indonesia
# Q68582, name=Ilse Werner, desc=German actress (1921-2005)
# Q738677, name=Chris John, desc=Petinju asal Indonesia
# Q3089681, name=Usmar Ismail, desc=pahlawan nasional Indonesia
# Q1051041, name=Nh. Dini, desc=sastrawan, novelis, dan feminis asal Indonesia
# Q334810, name=Abu Bakar Ba'asyir, desc=Tokoh Islam di Indonesia
# Q2367329, name=Jenderal Soedirman, desc=pahlawan nasional Indonesia
# Q1393679, name=Hendrawan, desc=Indonesian badminton player and coach
# Q4263053, name=Yuki Kato, desc=pemeran perempuan asal Indonesia
# Q441699, name=Tania Gunadi, desc=pemeran perempuan asal Amerika Serikat
# Q719320, name=Tony Gunawan, desc=badminton player
# Q2007313, name=Jan Just Bos, desc=Dutch rower, botanist and TV presenter (1939-2003)
# Q2145886, name=Rudy Hartono, desc=Indonesian badminton player
# Q732000, name=Candra Wijaya, desc=badminton player
# Q7475947, name=Syahrini, desc=Penyanyi wanita Indonesia
# Q97192066, name=Rahmat Erwin Abdullah, desc=Indonesian weightlifter (born 2000)
# Q920361, name=Dik Esser, desc=field hockey player (1918-1979)
# Q1229813, name=Rexy Mainaky, desc=badminton player
# Q1771129, name=Sultan Agung dari Mataram, desc=Sultan dari Mataram dan pahlawan nasional Indonesia
# Q2605467, name=Adrianus de Jong, desc=Dutch fencer
# Q1334387, name=Vasily Pavlovich Rochev, desc=cross-country skier
# Q375774, name=Iskandar Muda dari Aceh, desc=Pahlawan Revolusi Kemerdekaan
# Q431353, name=Triyatno, desc=atlet angkat besi Indonesia
# Q591530, name=Musdah Mulia, desc=aktivis perempuan, peneliti, konselor, dan penulis di bidang keagamaan (Islam) di Indonesia
# Q680490, name=Ruurd Leegstra, desc=Dutch rower (1877-1933)
# Q936816, name=Gita Gutawa, desc=pemeran perempuan asal Indonesia
# Q957483, name=Ali Alatas, desc=diplomat Indonesia
# Q1350057, name=Utut Adianto, desc=Indonesian chess grandmaster and politician
# Q1413862, name=Corrie Laddé, desc=Dutch swimmer
# Q3040291, name=Nurfitriyana Saiman, desc=pemanah perempuan asal Indonesia
# Q3237077, name=Bunga Citra Lestari, desc=penyanyi dan pemeran perempuan asal Indonesia
# Q3502322, name=Mari Elka Pangestu, desc=Menteri Pariwisata dan Ekonomi Kreatif Indonesia ke-10, Menteri Perdagangan Indonesia ke-26
# Q2058688, name=Frans Alfred Meeng, desc=pemain sepak bola Hindia Belanda
# Q7441028, name=Sean Gelael, desc=Pembalap Mobil
# Q1341683, name=Eng Hian, desc=Indonesian badminton player
# Q2046283, name=Sapardi Djoko Damono, desc=penyair Indonesia
# Q4917827, name=Krisdayanti, desc=penyanyi dan pemeran perempuan asal Indonesia
# Q3940192, name=Rohit Chand, desc=Pesepakbola Nepal
# Q2670453, name=Djoeanda Kartawidjaja, desc=pahlawan nasional Indonesia
# Q489213, name=Edu Snethlage, desc=Dutch footballer (1886-1941)
# Q1335187, name=Justinus Darmojuwono, desc=Kardinal Katolik Roma
# Q19974584, name=Lukman Niode, desc=perenang Indonesia
# Q1347236, name=Jan Gualtherus van Breda Kolff, desc=Dutch footballer (1894-1976)
# Q77996, name=Friedrich Carl Andreas, desc=German orientalist and linguist
# Q457756, name=Raema Lisa Rumbewas, desc=atlet angkat besi asal Indonesia
# Q1049695, name=Tia Tanaka, desc=American pornographic actress
# Q2128765, name=Ismail Marzuki, desc=komponis dan penulis lagu Indonesia
# Q15990566, name=Aleta Baun, desc=Aktivis Llingkungan
# Q81199676, name=Reynhard Sinaga, desc=pelaku kriminal Indonesia
# Q176412, name=Gesang, desc=penyanyi-pencipta lagu Indonesia
# Q425634, name=Wynne Prakusya, desc=pemain tenis asal Indonesia
# Q2067820, name=W. S. Rendra, desc=penyair dan pemeran asal Indonesia
# Q4201169, name=Tien Soeharto, desc=Pahlawan Revolusi Kemerdekaan
# Q5645435, name=Prof. Dr. Hamka, desc=ulama, wartawan, sastrawan
# Q3503054, name=Mohammad Yamin, desc=pahlawan nasional Indonesia
# Q1966045, name=Christine Marie Berkhout, desc=ahli biologi asal Kerajaan Belanda
# Q961856, name=Ricky Subagja, desc=badminton player
# Q2042915, name=André Boerstra, desc=Dutch field hockey player
# Q5262511, name=Sherina Munaf, desc=penyanyi dan pemeran perempuan asal Indonesia
# Q524312, name=Nitya Krishinda Maheswari, desc=pemain bulu tangkis asal Indonesia
# Q6116223, name=Roekiah, desc=pemeran perempuan asal Indonesia
# Q1352833, name=Just Göbel, desc=Dutch footballer (1891-1984)
# Q1352954, name=Johan Adolph Frederik Kok, desc=Dutch footballer (1889-1958)
# Q1282508, name=Johan Wilhelm Eduard Sol, desc=Dutch footballer (1881-1965)
# Q3085419, name=Lilies Handayani, desc=pemanah perempuan asal Indonesia
# Q4200758, name=Ani Yudhoyono, desc=Ibu Negara Republik Indonesia ke-6
# Q76344, name=Hamzah Haz, desc=Wakil Presiden Indonesia ke-9
# Q55441062, name=Lalu Muhammad Zohri, desc=pelari Indonesia
# Q1427090, name=Flandy Limpele, desc=badminton player
# Q3085192, name=Kusuma Wardhani, desc=pemanah perempuan asal Indonesia
# Q203527, name=Nicolaas Jan Jerôme Bouvij, desc=Dutch footballer (1892-1957)
# Q2648661, name=Teuku Umar, desc=Pahlawan Revolusi Kemerdekaan
# Q983087, name=Nazril Irham, desc=penyanyi Indonesia
# Q3140305, name=Dewi Sartika, desc=Pahlawan Revolusi Kemerdekaan
# Q979967, name=Hermawan Susanto, desc=badminton player
# Q1052659, name=Cees ten Cate, desc=Dutch footballer (1890-1972)
# Q1283081, name=Eddy Hartono, desc=badminton player
# Q11713880, name=Irene Kharisma Sukandar, desc=pecatur Indonesia
# Q15646541, name=Puan Maharani, desc=politisi Indonesia
# Q704791, name=Leo Bosschart, desc=Dutch footballer (1888-1951)
# Q4264466, name=Malahayati, desc=Pahlawan Revolusi Kemerdekaan
# Q1352820, name=Frans de Bruijn Kops, desc=Dutch footballer (1886-1979)
# Q954295, name=John Juanda, desc=American-Indonesian poker player
# Q2083488, name=Ben Verweij, desc=Dutch footballer (1895-1951)
# Q26838133, name=Aldila Sutjiadi, desc=Pemain tenis Indonesia
# Q76306, name=Umar Wirahadikusumah, desc=politisi Indonesia
# Q71619, name=Wilhelm Homberg, desc=Alkimiawan Belanda
# Q202355, name=Arthur van Schendel, desc=Dutch writer
# Q336042, name=Aburizal Bakrie, desc=politikus dan pebisnis Indonesia
# Q485781, name=Ananda Mikola, desc=Pembalap mobil profesional dan pemeran laki-laki asal Indonesia
# Q816446, name=Bernard Bot, desc=Dutch diplomat
# Q1862046, name=Rob Slotemaker, desc=Dutch racing driver
# Q4201140, name=Taufiq Kiemas, desc=politikus Indonesia
# Q52586206, name=Niki, desc=penyanyi dan penulis lagu Indonesia
# Q4374536, name=Maudy Ayunda, desc=penyanyi Indonesia
# Q5113178, name=Christopher Rungkat, desc=Indonesian tennis player
# Q2614742, name=Julius Theodoor Ancion, desc=field hockey player (1924-2011)
# Q2094298, name=Rudy Gunawan, desc=badminton player
# Q2367341, name=Albertus Soegijapranata, desc=uskup Indonesia
# Q392335, name=Nafa Urbach, desc=pemeran perempuan asal Indonesia
# Q2670449, name=Taufiq Ismail, desc=penyair, penulis, dan aktivis
# Q452839, name=Wybo Veldman, desc=New Zealand rower
# Q76317, name=Soedharmono, desc=Wakil Presiden Indonesia ke-5
# Q1177170, name=David Wijnveldt, desc=Dutch footballer (1891-1962)
# Q2467467, name=André Joseph Guillaume Henri Kostermans, desc=Dutch botanist (1907-1994)
# Q30945670, name=Zhong Chenle, desc=Chinese singer and actor
# Q1953315, name=Munir Said Thalib, desc=Politisi Indonesia
# Q5262520, name=Nike Ardilla, desc=penyanyi dan pemeran perempuan asal Indonesia
# Q818410, name=Benyamin Sueb, desc=pemeran laki-laki asal Indonesia
# Q580563, name=Inul Daratista, desc=penyanyi Indonesia
# Q1209725, name=Richard MacNeill, desc=Dutch footballer (1898-1963)
# Q3141350, name=Jodi Ann Paterson, desc=pemeran perempuan asal Amerika Serikat
# Q977126, name=Hein ter Poorten, desc=Dutch general
# Q1755541, name=Suzanna, desc=pemeran perempuan asal Indonesia
# Q2179883, name=Herman Meyboom, desc=Belgian water polo player
# Q4695259, name=Ahmad Albar, desc=penyanyi asal Indonesia
# Q1522399, name=Walter Thijssen, desc=Dutch rower
# Q1352122, name=Miel Mundt, desc=Dutch footballer (1880-1949)
# Q5111696, name=Luna Maya, desc=pemeran perempuan asal Indonesia
# Q2784089, name=Pattimura, desc=Pahlawan Revolusi Kemerdekaan
# Q1755191, name=Sutan Takdir Alisjahbana, desc=sastrawan Indonesia
# Q520550, name=Henricus Tromp, desc=Dutch rower (1878-1962)
# Q12507726, name=Raisa Andriana, desc=penyanyi Indonesia
# Q14978306, name=Jonatan Christie, desc=Indonesian badminton player
# Q732439, name=Hasan Muhammad di Tiro, desc=pendiri Gerakan Aceh Merdeka
# Q508725, name=Rachel Blakely, desc=Australian actress
# Q400815, name=Dukun AS, desc=Ahmad Suradji
# Q1036773, name=Carl Anton Wilhelm Hirschmann, desc=Banker, General Secretary of FIFA (1877-1951)
# Q2001344, name=Artika Sari Devi, desc=pemeran perempuan asal Indonesia
# Q4755130, name=Andrea Hirata, desc=penulis Indonesia
# Q2992817, name=Ahmad Yani, desc=pahlawan nasional Indonesia
# Q4992140, name=Rosihan Anwar, desc=Jurnalis, editor, dan penulis kontemporer Indonesia
# Q2509252, name=Hamengkubuwana II, desc=sultan Yogyakarta
# Q468329, name=Vita Marissa, desc=mantan pemain bulu tangkis asal Indonesia
# Q517317, name=Rano Karno, desc=politikus dan pemeran laki-laki asal Indonesia
# Q973183, name=Rein van Bemmelen, desc=Dutch geologist (1904-1983)
# Q1752594, name=Tommy Sugiarto, desc=Indonesian badminton player
# Q2746623, name=Dian Sastrowardoyo, desc=pemeran perempuan asal Indonesia
# Q707282, name=Lo Lieh, desc=pemeran laki-laki asal Indonesia
# Q6761642, name=Maria Ulfah Santoso, desc=mantan Menteri Sosial pada Kabinet Sjahrir II dan anggota BPUPKI
# Q9015409, name=Rachel Amanda, desc=pemeran perempuan asal Indonesia
# Q289858, name=Soekiman Wirjosandjojo, desc=Perdana Menteri Indonesia ke-6
# Q183581, name=Hassan Wirajuda, desc=Politikus
# Q2978474, name=Abdoel Halim, desc=politisi Indonesia
# Q909047, name=Dorce Gamalama, desc=penyanyi dan pelawak Indonesia
# Q5431566, name=Fakih Usman, desc=politisi Indonesia
# Q706168, name=Conrad Helfrich, desc=Dutch Luitenant-Admiraal of World War II
# Q3294779, name=Hasri Ainun Habibie, desc=Ibu Negara Indonesia ke-3
# Q3353214, name=Emile Duson, desc=field hockey player
# Q85994941, name=Tiara Andini, desc=penyanyi dan pemeran perempuan asal Indonesia
# Q97307421, name=Happy Asmara, desc=penyanyi-penulis lagu Indonesia
# Q454136, name=Liesbeth List, desc=Dutch singer
# Q643644, name=Johan Fabricius, desc=Dutch writer, journalist and adventurer
# Q3505523, name=Budi Sudarsono, desc=Indonesian footballer
# Q6641514, name=Afgansyah Reza, desc=penyanyi Indonesia
# Q11310259, name=Jan Ruff O'Herne, desc=Dutch-Australian human rights activist campaigning against war rape
# Q76333, name=Try Sutrisno, desc=Wakil Presiden Indonesia ke-6
# Q639329, name=Meinoud Rost van Tonningen, desc=Dutch Nazi (1894-1945)
# Q2204754, name=Roderick Rijnders, desc=Dutch rower
# Q11213850, name=Indriati Iskak, desc=pemeran perempuan asal Indonesia
# Q4250968, name=Achmad Soebardjo, desc=Pahlawan Revolusi Kemerdekaan
# Q4699763, name=Ajip Rosidi, desc=pengarang Indonesia
# Q459474, name=Widya Saputra, desc=presenter televisi Indonesia
# Q545750, name=Dries Holten, desc=Dutch singer and songwriter (1936-2020)
# Q465053, name=Tri Kusharyanto, desc=badminton player
# Q2669336, name=Garin Nugroho, desc=sutradara film Indonesia
# Q4695300, name=Ahmad Dahlan, desc=ulama Indonesia, pendiri Muhammadiyah
# Q1806448, name=Antonius Colenbrander, desc=Dutch equestrian
# Q28962233, name=Robertus Rubiyatmoko, desc=21st-century Indonesian Catholic bishop
# Q2826050, name=Affandi, desc=pelukis Indonesia
# Q5653028, name=Happy Salma, desc=pemeran perempuan asal Indonesia
# Q5629065, name=Hans Bague Jassin, desc=Pahlawan Revolusi Kemerdekaan
# Q2915833, name=Untung Suropati, desc=Pahlawan Revolusi Kemerdekaan
# Q7416335, name=Sandiaga Uno, desc=pengusaha, politisi, dan Menteri Pariwisata dan Ekonomi Kreatif Indonesia ke-13,
# Q6147504, name=Titiek Puspa, desc=pemeran perempuan asal Indonesia
# Q965563, name=Buchtar Tabuni, desc=politisi Indonesia
# Q1942017, name=Ted Dekker, desc=American writer
# Q11216625, name=Ikke Nurjanah, desc=penyanyi dan aktris Indonesia
# Q1254045, name=Johan Carp, desc=sailor
# Q1393182, name=Ali Sadikin, desc=Pahlawan Revolusi Kemerdekaan
# Q2669297, name=Burhanuddin Harahap, desc=Perdana Menteri Indonesia ke-9
# Q1284250, name=Eddy du Perron, desc=Dutch writer (1899-1940)
# Q2277434, name=Soe Hok Gie, desc=Aktivis Indonesia
# Q2307624, name=Jenne Langhout, desc=field hockey player (1918-2010)
# Q2573084, name=Marius Klumperbeek, desc=Dutch rower
# Q3317190, name=Chelsea Olivia, desc=pemeran perempuan asal Indonesia
# Q4259936, name=Atiqah Hasiholan, desc=pemeran perempuan asal Indonesia
# Q61997527, name=Frederika Alexis Cull, desc=model dan pemenang kontes kecantikan Puteri Indonesia 2019
# Q38693736, name=Egy Maulana Vikri, desc=pemain sepak bola Indonesia
# Q25470942, name=Ratu Sikumbang, desc=penyanyi Indonesia
# Q5661029, name=Didi Kempot, desc=penyanyi-penulis lagu Indonesia
# Q19744463, name=Tulus, desc=penyanyi Indonesia
# Q3738184, name=Yos Sudarso, desc=Pahlawan Revolusi Kemerdekaan
# Q1850137, name=René Sparenberg, desc=Dutch field hockey player
# Q981398, name=Wahid Hasjim, desc=Pahlawan Revolusi Kemerdekaan
# Q461147, name=S. Antonius Budi Ariantho, desc=badminton player
# Q4250932, name=Oerip Soemohardjo, desc=pahlawan nasional Indonesia
# Q5104091, name=Choirul Huda, desc=Indonesian footballer (1979-2017)
# Q7585525, name=Goenawan Mohamad, desc=Indonesian journalist, editor and poet
# Q12522317, name=Tri Rismaharini, desc=Menteri Sosial Indonesia ke-31
# Q1925269, name=Hans Croon, desc=Dutch football manager (1936-1985)
# Q2603591, name=Oemar Said Tjokroaminoto, desc=Pahlawan Revolusi Kemerdekaan
# Q56394496, name=Nissa Sabyan, desc=penyanyi Indonesia
# Q1398584, name=Musso, desc=Politisi Indonesia
# Q12498500, name=Mieke Wijaya, desc=pemeran perempuan asal Indonesia
# Q254353, name=Minarti Timur, desc=pemain dan pelatih bulu tangkis asal Indonesia
# Q553892, name=Lipke Holthuis, desc=ahli biologi asal Kerajaan Belanda
# Q696748, name=Wang Gungwu, desc=Singaporean academic
# Q933276, name=Jack Kolle, desc=Indonesian footballer
# Q3181117, name=Sutomo, desc=pahlawan nasional Indonesia
# Q4695305, name=Ahmad Dhani, desc=musikus Indonesia
# Q29145414, name=Kevin Lilliana, desc=model dan pemenang kontes kecantikan Miss International 2017 asal Indonesia
# Q4201122, name=Hanung Bramantyo, desc=sutradara laki-laki asal Indonesia
# Q706175, name=Victor Albert Gonsalves, desc=Dutch footballer
# Q3093044, name=Gerrit Faulhaber, desc=Indonesian footballer (1912-1951)
# Q4202141, name=Sam Ratulangi, desc=Pahlawan Revolusi Kemerdekaan
# Q4264456, name=Evie Tamala, desc=penyanyi asal Indonesia
# Q12525054, name=Yayan Ruhian, desc=pemeran laki-laki asal Indonesia
# Q769919, name=Frans G. Hu Kon, desc=Indonesian footballer
# Q4931574, name=Boaz Solossa, desc=Pesepakbola Indonesia
# Q2489084, name=Asrul Sani, desc=Pahlawan Revolusi Kemerdekaan
# Q4264085, name=Adenan Kapau Gani, desc=pahlawan nasional Indonesia
# Q4201482, name=Syafruddin Prawiranegara, desc=pahlawan nasional Indonesia
# Q4131734, name=Ebiet G. Ade, desc=penyanyi Indonesia
# Q525472, name=Maurice Gatsonides, desc=Dutch rally driver and inventor (1911-1998)
# Q449688, name=Marinus Anton Donk, desc=Dutch mycologist (1908-1972)
# Q608792, name=Hubertus Leteng, desc=Indonesian priest
# Q4754513, name=Andjar Asmara, desc=Seorang Actor dan Jurnalis yang berasal dari Indonesia
# Q3656008, name=Tjoet Nyak Meutia, desc=Pahlawan Revolusi Kemerdekaan
# Q87184, name=Erika Remberg, desc=Austrian actress
# Q585982, name=Bona Septano, desc=badminton player
# Q145877, name=Imam Bonjol, desc=Pahlawan Revolusi Kemerdekaan
# Q2605059, name=R. Suprapto, desc=pahlawan nasional Indonesia
# Q5068118, name=Chaerul Saleh, desc=Pahlawan Revolusi Kemerdekaan
# Q12525366, name=Yustinus Hardjosusanto, desc=21st-century Indonesian Catholic archbishop
# Q576362, name=Boudewijn de Groot, desc=Dutch singer and songwriter
# Q1375653, name=Shane Gallagher, desc=American musician
# Q2524065, name=Anthonie Cornelis Oudemans, desc=Dutch zoologist
# Q2746631, name=Elvy Sukaesih, desc=pemeran perempuan asal Indonesia
# Q4131627, name=Irwandi Yusuf, desc=politisi Indonesia
# Q15222841, name=Paskalis Bruno Syukur, desc=Uskup Keuskupan Bogor sejak tahun 2013
# Q9331376, name=Citra Febrianti, desc=atlet angkat besi Indonesia
# Q4673343, name=Acha Septriasa, desc=pemeran perempuan asal Indonesia
# Q5111684, name=Iwan Fals, desc=penyanyi dan musisi Indonesia
# Q5263767, name=Nicholas Saputra, desc=Pemeran laki-laki asal Indonesia (lahir 1984)
# Q5568820, name=Glenn Fredly, desc=penyanyi dan musisi Indonesia
# Q6308160, name=Julie Estelle, desc=pemeran perempuan asal Indonesia
# Q520248, name=Debby Susanto, desc=pemain bulu tangkis asal Indonesia
# Q4199270, name=Bing Slamet, desc=aktor film, penyanyi, dan komedian asal Indonesia
# Q2254732, name=Cor Braasem, desc=Dutch water polo player (1923-2009)
# Q1284438, name=Edhi Handoko, desc=Indonesian chess player
# Q1976278, name=Pakubuwana VI, desc=Susuhunan dari Surakarta
# Q3044724, name=Suryo Agung Wibowo, desc=Indonesian sprinter
# Q4383337, name=Johannes Pujasumarta, desc=archbishop from Indonesia
# Q12506448, name=Prilly Latuconsina, desc=pemeran perempuan asal Indonesia
# Q2038341, name=Simon Santoso, desc=mantan pemain bulu tangkis Indonesia
# Q3341990, name=Nini Theilade, desc=Danish ballet dancer (1915-2018)
# Q983494, name=Kurniawan Dwi Yulianto, desc=Indonesian footballer and manager
# Q5830827, name=Emilia Contessa, desc=pemeran perempuan asal Indonesia
# Q4251141, name=Marah Roesli, desc=Indonesian writer
# Q3025589, name=Dewi Persik, desc=pemeran perempuan asal Indonesia
# Q281224, name=Heryanto Arbi, desc=Pemain bulu tangkis asal Indonesia
# Q56015542, name=Puti Kaisar Mihara, desc=martial artist
# Q591152, name=Dulmatin, desc=Teroris asal Indonesia
# Q4201183, name=Soepomo, desc=Pahlawan Revolusi Kemerdekaan
# Q983460, name=Luluk Hadiyanto, desc=badminton player from Indonesia
# Q12521646, name=Tirto Adhi Soerjo, desc=Pahlawan Revolusi Kemerdekaan
# Q4200346, name=Ari Lasso, desc=penyanyi Indonesia
# Q581677, name=Jacobus Hendricus van Lint, desc=Dutch mathematician
# Q1390640, name=Raffi Ahmad, desc=pemeran laki-laki asal Indonesia
# Q4794037, name=Melly Goeslaw, desc=penyanyi-penulis lagu dan pemeran perempuan asal Indonesia
# Q85989007, name=Ayu Maulida, desc=model dan pemenang kontes kecantikan Puteri Indonesia 2020
# Q707205, name=Ronald Susilo, desc=Singaporean badminton player
# Q2253449, name=Ernest Douwes Dekker, desc=Pahlawan Revolusi Kemerdekaan
# Q6862289, name=Poppy Mercury, desc=penyanyi perempuan asal Indonesia
# Q461579, name=Madelon Szekely-Lulofs, desc=penulis indonesia
# Q2491603, name=Oscar van Rappard, desc=Dutch hurdler and footballer (1896-1962)
# Q6543801, name=Lie Kim Hok, desc=Chinese-Indonesian writer and teacher (1853–1912)
# Q2921156, name=Vic Hayes, desc=Father of Wi-Fi
# Q4349443, name=Maia Estianty, desc=pemeran perempuan asal Indonesia
# Q7299896, name=Rd Ariffien, desc=Indonesian film director
# Q15065475, name=Evan Dimas Darmono, desc=pemain sepak bola Indonesia
# Q661401, name=Hamengkubuwana VIII, desc=sultan Yogyakarta
# Q2012278, name=Hamengkubuwana IV, desc=sultan Yogyakarta
# Q2430565, name=Hamengkubuwana III, desc=sultan Yogyakarta
# Q2650710, name=Aloysius Sudarso, desc=Indonesian priest
# Q461435, name=Denny Kantono, desc=badminton player
# Q4252095, name=Ayu Ting Ting, desc=penyanyi asal Indonesia
# Q1616295, name=Sultan Hasanuddin, desc=Pahlawan Revolusi Kemerdekaan
# Q2642883, name=Johannes Leimena, desc=pahlawan nasional Indonesia
# Q19922013, name=Joey Alexander, desc=indonesian jazz pianist
# Q7262516, name=Putu Wijaya, desc=Indonesian writer
# Q3505511, name=Elie Aiboy, desc=Indonesian footballer
# Q1810756, name=Max Westerkamp, desc=field hockey player
# Q2088806, name=Bernard Carp, desc=Dutch sailor, olympic gold medalist, board member at Erven Lucas Bols, golfplayer and throphy hunter
# Q429584, name=Adityawarman, desc=Raja Tanah Emas
# Q17919, name=Charles Prosper Wolff Schoemaker, desc=Dutch architect (1882-1949), active in Bandung, Indonesia
# Q679059, name=Law Adam, desc=Dutch footballer (1908-1941)
# Q2997852, name=Muhammad Rachman, desc=Indonesian boxer
# Q2096629, name=Theys Hiyo Eluay, desc=politisi Indonesia
# Q2249375, name=Soetomo, desc=Pahlawan Revolusi Kemerdekaan
# Q539542, name=Sririta Jensen, desc=Thai model
# Q1442321, name=Franciscus Kopong Kung, desc=21st-century Indonesian Catholic bishop
# Q1700309, name=Pius Riana Prapdi, desc=Indonesian bishop
# Q2526775, name=Vincentius Sensi Potokota, desc=21st-century Indonesian Catholic archbishop
# Q2944547, name=Alexander Aan, desc=Indonesian atheist and prisoner
# Q3177695, name=Tommy Soeharto, desc=Politikus dan pengusaha Indonesia
# Q3847849, name=Dede Supriatna, desc=
# Q4973876, name=Kamidia Radisti, desc=pemeran perempuan asal Indonesia
# Q12494860, name=Lilis Suryani, desc=penyanyi Indonesia
# Q11774724, name=Nana Lee, desc=pemeran perempuan asal Indonesia
# Q12514086, name=Shandy Aulia, desc=pemeran perempuan asal Indonesia
# Q12497727, name=Medina Warda Aulia, desc=pecatur putri asal Indonesia
# Q18558886, name=Ruselli Hartawan, desc=pemain bulu tangkis asal Indonesia
# Q5447406, name=Fifi Young, desc=pemeran perempuan asal Indonesia
# Q20880258, name=Frans Mohede, desc=penyanyi dan pemeran laki-laki asal Indonesia
# Q275463, name=Sandra Dewi, desc=pemeran perempuan asal Indonesia
# Q2343180, name=Frits Ruimschotel, desc=Dutch water polo player (1922-1987)
# Q1521256, name=Umar Kayam, desc=pemeran laki-laki asal Indonesia
# Q2603618, name=Siswondo Parman, desc=pahlawan nasional Indonesia
# Q3107476, name=Juwono Sudarsono, desc=politisi Indonesia
# Q4187311, name=Emil Salim, desc=ekonom dan politisi senior Indonesia
# Q4263863, name=Cerdas Barus, desc=Indonesian chess player
# Q43131822, name=Abdul Somad Batubara, desc=pendakwah dan ulama asal Indonesia
# Q1179734, name=Muhammad Balfas, desc=author
# Q1279930, name=Moreno Soeprapto, desc=Mantan pembalap mobil profesional asal Indonesia
# Q1392988, name=Fauzi Bowo, desc=Mantan Gubernur DKI Jakarta, Wakil Gubernur DKI Jakarta
# Q2060158, name=Adriaan Maas, desc=Olympic sailor
# Q2603600, name=Pierre Tendean, desc=pahlawan nasional Indonesia
# Q3793280, name=Reza Rahadian, desc=pemeran laki-laki asal Indonesia
# Q3958239, name=Cut Tari, desc=pemeran perempuan asal Indonesia
# Q4198154, name=Indra Lesmana, desc=Musisi jazz Indonesia
# Q4199003, name=Sjumandjaja, desc=pemeran laki-laki asal Indonesia
# Q4199390, name=Tora Sudiro, desc=pemeran laki-laki asal Indonesia
# Q4201152, name=Nia Dinata, desc=sutradara film asal Indonesia
# Q11036795, name=Joko Anwar, desc=sutradara asal Indonesia
# Q4251025, name=Titi DJ, desc=Penyanyi asal Indonesia
# Q4311053, name=Adia Chan, desc=Hong Kong actress and singer
# Q4382677, name=Maya Soetoro-Ng, desc=teacher and half-sister of Barack Obama
# Q5025906, name=Camelia Malik, desc=penyanyi Indonesia
# Q5068119, name=Chairul Tanjung, desc=pengusaha dan birokrat Indonesia
# Q6187937, name=Jessy Rompies, desc=Indonesian tennis player
# Q6372516, name=Karlina Supelli, desc=filsuf dan astronomer asal Indonesia
# Q6509386, name=Idris Sardi, desc=komposer asal Indonesia
# Q6745424, name=Maman Abdurrahman Dulur si wahid, desc=football player
# Q4201732, name=Hatta Rajasa, desc=politikus Indonesia
# Q7419814, name=Ryamizard Ryacudu, desc=Mantan Menteri Pertahanan Republik Indonesia
# Q7809983, name=Titi Kamal, desc=pemeran perempuan asal Indonesia
# Q9027531, name=Mansyur S, desc=Indonesian singer
# Q4263166, name=D. Djajakusuma, desc=pemeran laki-laki asal Indonesia
# Q2627581, name=Omar Dhani, desc=politisi Indonesia
# Q3118591, name=Siti Fadilah, desc=Menteri Kesehatan Indonesia ke-15
# Q3472874, name=Widji Thukul, desc=penyair dan aktivis asal Indonesia
# Q3655984, name=Nyi Ageng Serang, desc=pahlawan nasional Indonesia
# Q4196055, name=Djoko Santoso, desc=tokoh militer Indonesia
# Q7207401, name=Poerbatjaraka, desc=Indonesian academic
# Q587188, name=Cakka Nuraga, desc=Indonesian singer
# Q1708087, name=Joseph Theodorus Suwatan, desc=Indonesian Roman Catholic bishop
# Q18325159, name=Pah Wongso, desc=pemeran laki-laki asal Indonesia
# Q11108578, name=Aminah Cendrakasih, desc=pemeran perempuan asal Indonesia
# Q2838542, name=Zubir Said, desc=Komponis musik | Pengarang musik "Majulah Singapura"
# Q15229725, name=Kevin Sanjaya Sukamuljo, desc=pemain bulu tangkis asal Indonesia
# Q77836, name=Carl Langbehn, desc=German resistance member (1901-1944)
# Q49254232, name=Upiak Isil, desc=Penyanyi dari Indonesia
# Q538910, name=Ellen Angelina, desc=pemain bulu tangkis asal Indonesia
# Q468481, name=Ali Moertopo, desc=Pahlawan Revolusi Kemerdekaan
# Q12483474, name=Ganjar Pranowo, desc=Gubernur ke-15 Jawa Tengah, Indonesia
# Q4115277, name=Hidayat Nur Wahid, desc=politikus Indonesia
# Q17410605, name=Iriana, desc=ibu negara Indonesia ke-7
# Q978833, name=Hendri Kurniawan Saputra, desc=badminton player
# Q7476096, name=Habiburrahman El Shirazy, desc=pemeran laki-laki asal Indonesia
# Q1387931, name=Nurcholish Madjid, desc=Muslim scholar
# Q2091244, name=Wilopo, desc=Pahlawan Revolusi Kemerdekaan
# Q7844727, name=Triyaningsih, desc=Indonesian distance runner
# Q1813144, name=Ru van der Haar, desc=field hockey player
# Q3745, name=Ahmad Heryawan, desc=mantan gubernur Jawa Barat
# Q1061473, name=Dewi Lestari, desc=Penulis, penyanyi, dan pengarang lagu asal Indonesia
# Q1133511, name=Cornelis Christiaan Berg, desc=Ahli Botani Belanda
# Q2342229, name=Halim Perdanakusuma, desc=Pahlawan Revolusi Kemerdekaan
# Q5262470, name=Ruth Sahanaya, desc=Penyanyi Indonesia
# Q500157, name=Talitha Getty, desc=Dutch actress (1940-1971)
# Q1182143, name=Dede Oetomo, desc=Indonesian LGBT rights activist
# Q7475943, name=Laudya Cynthia Bella, desc=pemeran perempuan asal Indonesia
# Q12498215, name=Meriam Bellina, desc=pemeran perempuan asal Indonesia
# Q868611, name=Praveen Jordan, desc=Indonesian badminton player
# Q4116080, name=Ponaryo Astaman, desc=Indonesian footballer
# Q578617, name=Lo La Chapelle, desc=Dutch footballer (1888-1966)
# Q17122267, name=Antonius Subianto Bunjamin, desc=Uskup Bandung sejak 2014
# Q19655501, name=Isyana Sarasvati, desc=penyanyi-penulis lagu Indonesia
# Q3440970, name=Romana Tedjakusuma, desc=pemain tennis Indonesia
# Q33160, name=Sule, desc=pelawak Indonesia
# Q2249484, name=Hamengkubuwana VI, desc=sultan Yogyakarta
# Q2581159, name=Hamengkubuwana V, desc=sultan Yogyakarta
# Q2584101, name=Hamengkubuwana VII, desc=sultan Yogyakarta
# Q4160009, name=Adrianus Djajasepoetra, desc=Catholic archbishop
# Q1687024, name=Jenny Dalenoord, desc=Dutch painter and illustrator (1918-2013)
# Q517755, name=Philippe Bär, desc=Catholic bishop
# Q3498286, name=Firman Utina, desc=Indonesian footballer
# Q6108912, name=Rima Melati, desc=pemeran perempuan asal Indonesia
# Q2370267, name=Riri Riza, desc=sutradara produser film Indonesia
# Q12499835, name=Nafsiah Mboi, desc=Menteri Kesehatan Indonesia ke-17
# Q4189316, name=Nico Thomas, desc=Indonesian boxer
# Q981536, name=Ida Anak Agung Gde Agung, desc=Pahlawan Revolusi Kemerdekaan
# Q2375169, name=I Gede Siman Sudartawa, desc=Indonesian swimmer
# Q745917, name=Filep Karma, desc=West Papuan independence activist
# Q1923816, name=Po Binasuor, desc=king of Champa
# Q6875185, name=Misbach Yusa Biran, desc=sutradara dan penulis asal Indonesia
# Q1441813, name=Franciscus Xaverius Sudartanta Hadisumarta, desc=Uskup Emeritus Manokwari-Sorong
# Q402998, name=Leonardus Benyamin Moerdani, desc=tokoh militer Indonesia
# Q3572174, name=Yenny Wahid, desc=politisi Indonesia
# Q608600, name=Susanto Megaranto, desc=Indonesian chess player
# Q4273010, name=Iis Dahlia, desc=penyanyi dan pemeran perempuan asal Indonesia
# Q4200552, name=Jero Wacik, desc=politisi Indonesia
# Q187415, name=Zelin Resiana, desc=pemain bulu tangkis asal Indonesia
# Q7585838, name=Sri Indriyani, desc=atlet angkat besi asal Indonesia
# Q12470581, name=Abdulrahman Saleh (pahlawan), desc=Pahlawan Revolusi Kemerdekaan
# Q12470600, name=Abimana Aryasatya, desc=pemeran laki-laki asal Indonesia
# Q12505429, name=Pevita Pearce, desc=pemeran perempuan asal Indonesia
# Q12507600, name=Rachmawati Soekarnoputri, desc=tokoh politik dan pengacara Indonesia (1950–2021)
# Q12500705, name=Nia Zulkarnaen, desc=pemeran perempuan asal Indonesia
# Q12523268, name=Unique Priscilla, desc=pemeran perempuan asal Indonesia
# Q12478398, name=Cassanova Alfonso, desc=penyanyi asal Indonesia
# Q13097203, name=Soerjadi Soedirdja, desc=Mantan Gubernur DKI Jakarta
# Q357640, name=Teuku Jacob, desc=Indonesian paleoanthropologist (1929-2007)
# Q4259946, name=Teuku Muhammad Hasan, desc=Pahlawan Revolusi Kemerdekaan
# Q3634460, name=Gedong Bagus Oka, desc=tokoh pembaruan Hindu dan gerakan anti kekerasan di Indonesia
# Q26227897, name=Memo, desc=pace panbar
# Q26254261, name=Rufino Gama, desc=association football player
# Q25468646, name=Stephanie Poetri, desc=penyanyi Indonesia
# Q117220, name=Pia Zebadiah, desc=pemain bulu tangkis asal Indonesia
# Q4201513, name=Sutoyo Siswomiharjo, desc=pahlawan nasional Indonesia
# Q5111674, name=Yuni Shara, desc=penyanyi Indonesia
# Q6892160, name=Mahfud MD, desc=Menteri Koordinator Politik, Hukum, dan Keamanan Republik Indonesia ke-14
# Q12480888, name=Dapunta Hyang, desc=emperor of Srivijaya empire
# Q12487847, name=Jessica Mila Agnesia, desc=pemeran perempuan asal Indonesia
# Q463093, name=Sigit Budiarto, desc=Indonesian badminton player
# Q11109918, name=Abdul Malik Fadjar, desc=Indonesian politician
# Q4990753, name=Rinni Wulandari, desc=penyanyi indonesia
# Q320928, name=Eddy de Neve, desc=Dutch footballer (1885-1943)
# Q353459, name=Ade Chandra, desc=badminton player
# Q469616, name=Endang Rahayu Sedyaningsih, desc=Menteri Kesehatan Indonesia ke-16 dan politisi Indonesia
# Q1061866, name=Christian Sugiono, desc=pemeran laki-laki asal Indonesia
# Q1334791, name=Satrio Hermanto, desc=Mantan pembalap mobil profesional asal Indonesia
# Q1396599, name=Linda Weni Fanetri, desc=pemain bulu tangkis asal Indonesia
# Q1523130, name=Marcus Fernaldi Gideon, desc=Indonesian badminton player
# Q1619725, name=Piet Salomons, desc=Dutch water polo player
# Q1635435, name=Djenar Maesa Ayu, desc=penulis dan pemeran perempuan asal Indonesia
# Q44988077, name=The Sacred Riana, desc=ilusionis Indonesia
# Q1993617, name=Mira Lesmana, desc=produser film Indonesia
# Q2053428, name=Qory Sandioriva, desc=aktris, model dan pemenang kontes kecantikan Puteri Indonesia 2009
# Q3545963, name=Leila S. Chudori, desc=penulis dan wartawan asal Indonesia
# Q3663579, name=Kamila Andini, desc=sutradara asal Indonesia
# Q1136098, name=Cosmas Michael Angkur, desc=Indonesian Roman Catholic bishop
# Q6854752, name=Idham Chalid, desc=Politisi dan ulama Indonesia
# Q15533047, name=Masita Mahmudin, desc=pemain bulu tangkis asal Indonesia
# Q4259877, name=Kurnia Meiga Hermansyah, desc=Pemain sepak bola Indonesia
# Q4264970, name=Pinkan Mambo, desc=penyanyi Indonesia
# Q4460863, name=Titi Rajo Bintang, desc=pemeran perempuan asal Indonesia
# Q4695486, name=Ahmad Taufik, desc=jurnalis Indonesia
# Q4815122, name=Marie Beatrice Schol-Schwarz, desc=Dutch phytopathologist (1898-1969)
# Q5249736, name=Deddy Mizwar, desc=pemeran laki-laki asal Indonesia
# Q961117, name=Rudy Kousbroek, desc=Dutch writer
# Q4724605, name=Ali Akbar Navis, desc=Sastrawan dan budayawan Indonesia
# Q5296722, name=Donny Alamsyah, desc=pemeran laki-laki asal Indonesia
# Q6136277, name=Surya Saputra, desc=pemeran laki-laki asal Indonesia
# Q2419755, name=Fiona Tan, desc=Indonesian sculptor
# Q2053679, name=Maria Selena, desc=model dan pemenang kontes kecantikan Puteri Indonesia 2011
# Q4198988, name=Tantowi Yahya, desc=Indonesian presenter and politician
# Q97222180, name=Lyodra Ginting, desc=penyanyi dan pemeran perempuan asal Indonesia
# Q7694770, name=Teguh Karya, desc=sutradara dan pemeran film asal Indonesia
# Q7476090, name=Shireen Sungkar, desc=pemeran perempuan asal Indonesia
# Q1106653, name=Coen Zuidema, desc=Dutch chess player
# Q1702607, name=Joko Suprianto, desc=Mantan atlet bulu tangkis Indonesia (lahir 1966)
# Q2202270, name=Amien Rais, desc=politikus asal Indonesia
# Q2330098, name=Pakubuwana X, desc=pahlawan nasional Indonesia
# Q2417617, name=Pakubuwana IX, desc=Susuhunan Surakarta
# Q3502316, name=Mardiyanto, desc=politisi Indonesia
# Q4726672, name=Alimin, desc=Pahlawan Revolusi Kemerdekaan
# Q6723714, name=Soesanto Tirtoprodjo, desc=politisi Indonesia
# Q7399523, name=Saharjo, desc=Pahlawan Revolusi Kemerdekaan
# Q1385041, name=Nicolaus Adi Seputra, desc=Indonesian priest
# Q12483575, name=Gatot Nurmantyo, desc=tokoh militer Indonesia
# Q448673, name=Alvent Yulianto, desc=Indonesian badminton player
# Q18421453, name=Subiakto Tjakrawerdaya, desc=Indonesian politician
# Q4189748, name=Roy Marten, desc=pemeran laki-laki asal Indonesia
# Q15882992, name=Toto Koopman, desc=Dutch model (1908-1991)
# Q4251401, name=Untung Syamsuri, desc=Tokoh yang terlibat dalam Gerakan 30sPki
# Q56400139, name=Aries Susanti Rahayu, desc=Pemanjat tebing Indonesia (lahir 1995)
# Q3231014, name=Roestam Effendi, desc=politisi Indonesia
# Q5989792, name=Idrus, desc=writer (1921-1979)
# Q4273018, name=Anang Hermansyah, desc=musikus, produser, dan politikus Indonesia
# Q706366, name=Liem Swie King, desc=pemain bulu tangkis asal Indonesia
# Q4815161, name=Elizabeth A. Widjaja, desc=peneliti, ahli bambu asal Indonesia
# Q503650, name=Max van Egmond, desc=Dutch singer (1936-)
# Q699041, name=Fuad Hassan, desc=politisi Indonesia Direktur Utama Indosiar
# Q1383895, name=Hubertus Johannes van Mook, desc=Dutch colonial governor (1894-1965)
# Q4423167, name=Winarni Binti Slamet, desc=atlet angkat besi asal Indonesia
# Q4264061, name=Sinta Nuriyah, desc=Ibu Negara Indonesia ke-4
# Q4272199, name=Gombloh, desc=Indonesian singer
# Q6761640, name=Maria Ulfah, desc=qoriah Indonesia (lahir 1955)
# Q15498314, name=Daryono, desc=Indonesian footballer
# Q5261540, name=Gatot Soebroto, desc=Pahlawan Nasional Indonesia
# Q441620, name=Shendy Puspa Irawati, desc=pemain bulu tangkis asal Indonesia
# Q1306699, name=Soebandrio, desc=politikus Indonesia (1914-2004)
# Q1022998, name=Nicky Astria, desc=penyanyi dan pemeran perempuan asal Indonesia
# Q3244615, name=Adipati Dolken, desc=pemeran laki-laki asal Indonesia
# Q4188193, name=Tamara Bleszynski, desc=pemeran perempuan asal Indonesia
# Q4232763, name=Sijfert Hendrik Koorders, desc=botanist (1863-1919)
# Q4272043, name=Djoko Iskandar, desc=Indonesian herpetologist
# Q4273038, name=Trie Utami, desc=penyanyi indonesia
# Q87672993, name=Corona Rintawan, desc=Dokter spesialis kedaruratan medis asal Indonesia
# Q6425253, name=Melody Nurramdhani Laksani, desc=penyanyi Indonesia
# Q7322170, name=Rianti Cartwright, desc=pemeran perempuan asal Indonesia
# Q7333042, name=Ridwan Kamil, desc=Gubernur Jawa Barat dari 2018 sampai sekarang
# Q7805962, name=Agus Harimurti Yudhoyono, desc=politikus Indonesia
# Q519540, name=Eliza Nathanael, desc=pemain bulu tangkis asal Indonesia
# Q664383, name=Hendrik Cornelis Siebers, desc=Dutch ornithologist (1890-1949)
# Q941903, name=Kick Stokhuyzen, desc=Dutch politician (1930-2009)
# Q967941, name=Roeslan Abdulgani, desc=Tentara dan politikus Indonesia
# Q1281022, name=Hugo van Lawick, desc=Dutch film director (1937-2002)
# Q1321945, name=John Wijngaards, desc=Catholic theologian
# Q1352144, name=Guus van Hecking Colenbrander, desc=Dutch footballer (1887-1945)
# Q2424939, name=Bima Sakti Tukiman, desc=Indonesian footballer
# Q12512127, name=Saphira Indah, desc=pemeran perempuan asal Indonesia
# Q1754466, name=Dolf van der Nagel, desc=Dutch footballer (1889-1949)
# Q3136157, name=Rudi Soedjarwo, desc=Indonesian film director
# Q3658142, name=Kwee Tek Hoay, desc=penulis dan jurnalis Indonesia (1886-1951)
# Q18421371, name=Setya Novanto, desc=Politisi Indonesia
# Q4261583, name=Olla Ramlan, desc=pemeran perempuan asal Indonesia
# Q2196837, name=André Wetzel, desc=Dutch footballer and manager
# Q2248705, name=Erik Hazelhoff Roelfzema, desc=Dutch wartime pilot, spy and writer
# Q2526777, name=Vincentius Sutikno Wisaksono, desc=Uskup Gereja Katolik Roma untuk Keuskupan Surabaya
# Q2603608, name=Mas Tirtodarmo Harjono, desc=pahlawan nasional Indonesia
# Q7438987, name=Soe Tjen Marching, desc=Musikus, penulis, feminis, dan sastrawan asal Indonesia
# Q12486743, name=Iqbaal Ramadhan, desc=penyanyi dan pemeran laki-laki asal Indonesia
# Q17411245, name=Samuel Oton Sidin, desc=Uskup Sintang
# Q6492661, name=Kusumah Atmaja, desc=Pahlawan Revolusi Kemerdekaan
# Q981547, name=Frans Seda, desc=politisi Indonesia
# Q7461716, name=Wilhelmus Zakaria Johannes, desc=Pahlawan Revolusi Kemerdekaan
# Q12485593, name=Herman Johannes, desc=Pahlawan Revolusi Kemerdekaan
# Q96989495, name=Ali Taher, desc=Indonesian politician
# Q1419304, name=Jack Jersey, desc=Dutch singer, music producer, composer, lyricist, music arranger, musician
# Q441642, name=Erna Spoorenberg, desc=Dutch singer and opera singer (1926-2004)
# Q731740, name=Wiranto, desc=politikus Indonesia
# Q1706622, name=Saeroen, desc=Journalist and screenwriter
# Q2140777, name=Paku Alam VIII, desc=Adipati dari Pakualaman ke-8 dan Gubernur Daerah Istimewa Yogyakarta ke-2
# Q3241958, name=Morgan Oey, desc=pemeran laki-laki asal Indonesia
# Q16724322, name=Ihsan Maulana Mustofa, desc=Pemain bulu tangkis asal Indonesia
# Q60307, name=Richi Puspita Dili, desc=pemain bulu tangkis asal Indonesia
# Q1620119, name=Hans Stam, desc=Dutch water polo player
# Q4790571, name=Arifin C. Noer, desc=tokoh seni teater indonesia
# Q12478640, name=Chitra Dewi, desc=pemeran perempuan asal Indonesia
# Q4264877, name=Desy Ratnasari, desc=pemeran perempuan asal Indonesia
# Q28976374, name=Ikhsan Rumbay, desc=pemain bulu tangkis asal Indonesia
# Q4116077, name=Syamsul Bachri Chaeruddin, desc=Indonesian footballer
# Q75989, name=Hans Gugelot, desc=German architect
# Q127986, name=David Jacobs, desc=Indonesian Paralympic table tennis player
# Q4975924, name=Paramitha Rusady, desc=pemeran perempuan asal Indonesia
# Q558988, name=Carel Herman Aart van der Wijck, desc=Dutch politician (1840-1914)
# Q3498278, name=Ricardo Salampessy, desc=Indonesian footballer
# Q4200660, name=Broery Marantika, desc=pemeran laki-laki asal Indonesia
# Q18177473, name=Maria Natalia Londa, desc=Indonesian female athlete
# Q1766782, name=Umar Patek, desc=Indonesian terrorist
# Q2313666, name=Jaya Suprana, desc=Indonesian businessman
# Q2084730, name=Oktovianus Maniani, desc=Indonesian footballer
# Q3083011, name=Frans Kaisiepo, desc=Pahlawan Revolusi Kemerdekaan
# Q4199372, name=Evan Sanders, desc=pemeran laki-laki asal Indonesia
# Q4200563, name=Ellyas Pical, desc=Indonesian boxer
# Q6771459, name=Markus Haris Maulana, desc=Indonesian footballer
# Q4250996, name=D.I. Pandjaitan, desc=pahlawan nasional Indonesia
# Q2649325, name=Ahmad Syafii Maarif, desc=ulama dan cendekiawan asal Indonesia (1935–2022)
# Q4250939, name=Adinegoro, desc=Reporter, writer, analyst
# Q4252062, name=Utuy Tatang Sontani, desc=writer (1920-1979)
# Q255619, name=Zaenal Arief, desc=Indonesian footballer
# Q528116, name=Rian Agung Saputra, desc=badminton player
# Q4202200, name=Hasyim Asyari, desc=Ulama Indonesia dan pendiri Nahdlatul Ulama
# Q6828395, name=Michael Bambang Hartono, desc=pebisnis asal Indonesia
# Q497951, name=Andreas Henrisusanta, desc=Uskup Emeritus Tanjungkarang
# Q4258815, name=Tjokorda Gde Raka Soekawati, desc=politisi Indonesia
# Q5350264, name=Eka Ramdani, desc=Indonesian footballer
# Q5268010, name=Dewa Budjana, desc=gitaris Indonesia
# Q4201241, name=Maria Walanda Maramis, desc=Pahlawan Revolusi Kemerdekaan
# Q21538605, name=Setyana Mapasa, desc=badminton player
# Q17410837, name=Nasrul Abit, desc=politisi Indonesia
# Q2604528, name=Willem van Outhoorn, desc=Dutch colonial governor
# Q818408, name=Benyamin Yosef Bria, desc=Roman Catholic bishop
# Q6543803, name=Lie Tek Swie, desc=
# Q16233583, name=Luke Smith, desc=Australian volleyball player
# Q26267479, name=Sudirman Hadi, desc=Indonesian Olympic sprinter
# Q12508562, name=Ria Irawan, desc=pemeran perempuan asal Indonesia
# Q12514113, name=Sheryl Sheinafia, desc=penyanyi dan pemeran perempuan asal Indonesia
# Q12912624, name=Ario Bayu, desc=pemeran laki-laki asal Indonesia
# Q13094789, name=Lydia Kandou, desc=pemeran perempuan asal Indonesia
# Q13095464, name=Nila Moeloek, desc=Menteri Kesehatan Indonesia ke-18  dan ahli oftalmologi
# Q14917401, name=Nia Daniati, desc=pemeran perempuan asal Indonesia
# Q15975470, name=Adrienne Jacqueline s' Jacob, desc=Dutch painter (1857-1920)
# Q19702167, name=Philo Paz Armand, desc=Indonesian racing driver
# Q468390, name=Mustafa Abubakar, desc=politisi Indonesia
# Q5227848, name=Daud Beureu'eh, desc=Politisi Indonesia
# Q19743809, name=Tara Basro, desc=Pemeran perempuan asal Indonesia
# Q12482563, name=Ermina Zaenah, desc=pemeran perempuan asal Indonesia
# Q4260406, name=Zulkifli Hasan, desc=Menteri Perdagangan Indonesia ke-34
# Q4806383, name=T.B. Simatupang, desc=pahlawan nasional Indonesia
# Q5629671, name=HIM Damsyik, desc=pemeran laki-laki asal Indonesia
# Q20716044, name=Rain Chudori, desc=penulis Indonesia
# Q201621, name=Alex McDowell, desc=British production designer
# Q2840640, name=Alwi Shihab, desc=Indonesian politician
# Q111550625, name=Nienke Brinkman, desc=Dutch marathon runner
# Q355715, name=Bernard Lievegoed, desc=Dutch physician
# Q820398, name=Walle Nauta, desc=Dutch neuroscientist
# Q10513620, name=Supardi Nasir, desc=Indonesian footballer
# Q149730, name=Njoo Cheong Seng, desc=Chinese Indonesian novelist, playwright, and director (1902-1962)
# Q2094306, name=Pieter van Royen, desc=Dutch botanist (1923-2002)
# Q2746664, name=Mohamad Roem, desc=politikus Indonesia
# Q11695743, name=Nini Carlina, desc=Indonesian musician
# Q28673279, name=Andri Syahputra, desc=association football player
# ...
# Q108889063, name=Zainuddin Siregar, desc=Indonesian politician (born 1951)
# Q108889159, name=Erwin Hasibuan, desc=Indonesian politician (born 1952 in Pasar Matanggor)
# Q108889311, name=Annisa Zakiah Pasaribu, desc=Indonesian politician (born 1991 in Pasar Matanggor)
# Q108899926, name=Sukadi Duadji, desc=Indonesian politician (born 1950 in Tebat Gunung)
# Q77394997, name=Asneli Luthan, desc=Seorang pengarang di Indonesia
# Q108889155, name=Leo Pandapotan Simangunsong, desc=Indonesian politician (born 1973 in Sialang Buah)
# Q108889653, name=Faisal Muharrami Saragih, desc=Indonesian politician (born 1978 in Petumbukan)
# Q108889359, name=Iskandar, desc=Indonesian politician (born 1973 in Selayang)
# Q108896581, name=Nelius Eli Ayomi, desc=Indonesian politician (born 1961 in Ansus)
# Q108889353, name=Hasan Basri Sirait, desc=Indonesian politician (born 1973 in Kapias Batu Viii)
# Q108889251, name=Nazly Lubis, desc=Indonesian politician (born 1965 in Meda)
# Q108896608, name=Editha Rahaded, desc=Indonesian politician (born 1951 in Kokonao)
# Q73413744, name=Barbara de Reus, desc=
# Q108896590, name=Alof St. Rumayomi, desc=Indonesian politician (born 1969)
# Q100396422, name=Kristoforus Yacobus Bao Kabelen, desc=Aktivis dan Pengacara muda dari Nusa Tenggara Timur.
# Q108895162, name=Budi Ikhlasiah, desc=Indonesian politician (born 1987 in Batu Nampar)
# Q38929946, name=Barend van Mecklenburg, desc=
# Q109450514, name=Aziza Djindan, desc=Indonesian politician (born 1993 in Limbung)
# Q108902042, name=Musleh Kholil, desc=Indonesian politician (born 1965 in Lelede)
# Q96988298, name=Samsu Niang, desc=Indonesian politician
# Q96988720, name=Supriansa, desc=Indonesian politician
# Q108896124, name=Rakhmad S. Topaweli, desc=Indonesian politician (born 1957 in Cilallang)
# Q108895133, name=Ani Hairani, desc=Indonesian politician (born 1962)
# Q96987338, name=Andi Muawiyah Ramly, desc=Indonesian politician
# Q97590768, name=Fary Djemy Francis, desc=Indonesian politician
# Q108894984, name=Hary Ashar, desc=Indonesian politician (born 1963 in Watampone)
# Q108895970, name=Ahmad Syahrir, desc=Indonesian politician (born 1977 in Watampone)
# Q108895973, name=Andi Syarifuddin Saguni, desc=Indonesian politician (born 1956 in Watampone)
# Q108895986, name=A.  Irsan Idris Galigo, desc=Indonesian politician (born 1973 in Watampone)
# Q108895994, name=Muh Yasir, desc=Indonesian politician (born 1957 in Watampone)
# Q108896001, name=Bahri Mappiasse, desc=Indonesian politician (born 1950 in Watampone)
# Q108896025, name=Yasir Mahmud, desc=Indonesian politician (born 1983 in Watampone)
# Q108896034, name=Nasiruddin Amiruddin, desc=Indonesian politician (born 1957 in Watampone)
# Q108896040, name=Muhammad Yahya Rasyid, desc=Indonesian politician (born 1965)
# Q108896134, name=Muhammad Yamin, desc=Indonesian politician (born 1966 in Cilellang)
# Q97590741, name=Edison Betaubun, desc=Indonesian politician
# Q108895200, name=Farida Khalid, desc=Indonesian politician (born 1972 in Kolikapa)
# Q108896465, name=Hilda Alkatiri, desc=Indonesian politician (born 1984 in Dofa)
# Q96989090, name=Achmad Hatari, desc=Indonesian politician
# Q108896189, name=Laode Asis, desc=Indonesian politician (born 1957 in Wapunto)
# Q108895866, name=Jattman Tampese, desc=Indonesian politician (born 1973 in Koromatantu)
# Q109700799, name=Marcus Silanno, desc=political candidate (from Kota Jakarta Timur; district Jatim I in 2009)
# Q97590545, name=Hamdhani, desc=Indonesian politician
# Q96989072, name=Ahmad Ali, desc=Indonesian politician
# Q108896052, name=Zulkipli, desc=Indonesian politician (born 1969 in Kosali)
# Q113711964, name=Irfan El Siami, desc=pelawak tunggal Indonesia
# Q108889840, name=Anang, desc=Indonesian politician (born 1964 in Penggage)
# Q108889841, name=Ruliana, desc=Indonesian politician (born 1989 in Ulak Embacang)
# Q108895663, name=Susianti, desc=Indonesian politician (born 1976 in Long Laai)
# Q108901517, name=Lilis Farida, desc=Indonesian politician (born 1966 in Jeriji)
# Q84593310, name=J.G. Dammerboer, desc=botanist (1867-1944)
# Q108894255, name=Silvia, desc=Indonesian politician (born 1979 in Lakapera)
# Q108896208, name=Wa Ode Alfiati Zaadi, desc=Indonesian politician (born 1971 in Poogalampa)
# Q108889301, name=Zakaria Bangun, desc=Indonesian politician (born 1955 in Buah Raya)
# Q108890060, name=Elsa Manora, desc=Indonesian politician (born 1990 in Tanjung Enim)
# Q108901458, name=Aini Zahrahayu, desc=Indonesian politician (born 1975 in Tanjung Enim)
# Q108891965, name=Daulat Sinuraya, desc=Indonesian politician (born 1953 in Singgamanik)
# Q106417873, name=Ahmad Yudhistira, desc=Indonesian motorcycle rider
# Q108895875, name=Abdul Hamid, desc=Indonesian politician (born 1982 in Bungayo)
# Q82574096, name=Nyoman Tulus, desc=
# Q108896345, name=A. Waris Hasan, desc=Indonesian politician (born 1947 in Pambusuang)
# Q108902855, name=Dolfintje Katrina Bolloy, desc=Indonesian politician (born 1956 in Enarotali)
# Q108902860, name=Noakh Nawipa, desc=Indonesian politician (born 1958 in Enarotali)
# Q108886932, name=Ni Nyoman Sukerti, desc=Indonesian politician (born 1954 in Pesedahan)
# Q108896004, name=Gede Mahendra Yasa, desc=indonesian artist
# Q82572862, name=I Dewa Kompiang, desc=
# Q108886935, name=I Nyoman Ray Yusha, desc=Indonesian politician (born 1953 in Tajun Singaraja)
# Q111429557, name=I Wayan Jana, desc=Indonesian artist
# Q82570324, name=I Wayan Bendi, desc=
# Q82575490, name=Ida Bagus Tampi, desc=
# Q104240197, name=Anak Agung Niang Rai, desc=
# Q108896048, name=Andi Erwin Marjun Patanjengi, desc=Indonesian politician (born 1963)
# Q85823562, name=Radja Mursinal Nasution, desc=pelatih renang Indonesia
# Q108896377, name=Rosina Ingratubun R, desc=Indonesian politician (born 1955 in Larat)
# Q108896442, name=Salim A. Halik, desc=Indonesian politician (born 1963 in Guruapin)
# Q106398119, name=W.J.S. van Alphen, desc=
# Q109938654, name=Herman Filip Deodaat Oxenaar, desc=
# Q108889421, name=Mahadi Manik, desc=Indonesian politician (born 1974)
# Q108889710, name=Ton Abdillah Has, desc=Indonesian politician (born 1981 in Bukit Kauman)
# Q108889743, name=Retno Dewanti, desc=Indonesian politician (born 1985 in Air Molek)
# Q49250820, name=Q49250820, desc=
# Q108889636, name=Helmawati, desc=Indonesian politician (born 1964 in Air Tiris)
# Q108889737, name=Sunarti S, desc=Indonesian politician (born 1949 in Air Tiris)
# Q108889736, name=Abdul Anas Badrun, desc=Indonesian politician (born 1964 in Tanjung Sum)
# Q108895545, name=Maulidayanti, desc=Indonesian politician (born 1988 in Bi-ih)
# Q108895491, name=Achmad Syarpani, desc=Indonesian politician (born 1952 in Birayang)
# Q108895531, name=Laila Irnawati, desc=Indonesian politician (born 1977 in Wawai)
# Q74804640, name=Elisabeth Porter, desc=Australian legal scholar
# Q108889239, name=Lubis, desc=Indonesian politician (born 1965 in Batu Satail)
# Q108889258, name=Sutor Siregar, desc=Indonesian politician (born 1956 in Panaungan)
# Q110963141, name=Idris Idham, desc=dokter
# Q64058134, name=Abdul Djalil Abdurraman, desc=ulama Indonesia
# Q64007969, name=Maksum Jauhari, desc=ulama pengasuh ponpes Lirboyo, Kediri
# Q64057996, name=KH. Abdullah Asy'ari Sohihul Alim, desc=Ulama
# Q64057895, name=KH. Abdul Fattah, desc=Pondok Pesantren Al-Fattah di Siman-Lamongan
# Q108889458, name=Yan Hiksas Dt Tan Ali, desc=Indonesian politician (born 1962)
# Q108890559, name=Darmizal Ms, desc=Indonesian politician (born 1963 in Sulit Air)
# Q108672913, name=Sri Fayola, desc=penyanyi Minang, Indonesia
# Q108889572, name=Iswarmi Badran, desc=Indonesian politician (born 1967 in Air Bangis)
# Q108894053, name=Devi Lestari, desc=Indonesian politician (born 1985)
# Q110896011, name=Holy Adib, desc=linguis Indonesia
# Q111271865, name=Hansastri, desc=birokrat Indonesia
# Q108889634, name=Zulkifli, desc=Indonesian politician (born 1954 in Sungai Pakning)
# Q110967402, name=Syofyan Hadi, desc=akademikus Indonesia
# Q79571818, name=Tuanku Mansiangan, desc=ulama
# Q90407313, name=Tuanku Mansiangan Nan Tuo, desc=ulama
# Q108889435, name=Ressy Arza, desc=Indonesian politician (born 1975)
# Q108889785, name=Hm. Najmi, desc=Indonesian politician (born 1958 in Rantau Duku)
# Q108892668, name=Ali Muntaha, desc=Indonesian politician (born 1970 in Mendalo Darat)
# Q108889759, name=Rina Susanti, desc=Indonesian politician (born 1978 in Tamiai)
# Q108889812, name=Sibawaihi, desc=Indonesian politician (born 1954 in Durian Batakuk)
# Q108889828, name=Dedi Masiuni, desc=Indonesian politician (born 1974 in Koto Baru Semurup)
# Q107584187, name=Nurul Almy Hafild, desc=aktivis lingkungan asal Indonesia
# Q108888959, name=Zulfa Aifi, desc=Indonesian politician (born in Manggis Harapan)
# Q108888974, name=Muhammad Adami, desc=Indonesian politician (born 1975 in Meunasah Beunot)
# Q108890285, name=Novita Apriyanti, desc=Indonesian politician (born 1990 in Ogan Campang)
# Q108890108, name=Hr Muchlis Ys., desc=Indonesian politician (born 1970 in Karang Dalo)
# Q108895555, name=Fathurrakhman, desc=Indonesian politician (born 1951)
# Q108895662, name=Muhammad Nasruddin, desc=Indonesian politician (born 1984 in Tanah Habang Kanan)
# Q114266787, name=Rahmani, desc=pegawai di Mahkamah Agung Ri
# Q108888834, name=Mahdalena, desc=Indonesian politician (born in Monmata)
# Q108888835, name=Tgk Husin Yusuf, desc=Indonesian politician (born 1955 in Ruak)
# Q64058196, name=Abdul Muchith Muzadi, desc=Tokoh Nadhlatul Ulama
# Q108891677, name=Safiul Akbar, desc=Indonesian politician (born 1973 in Raha)
# Q108896185, name=Habil Marati, desc=Indonesian politician (born 1962)
# Q108902705, name=Muhammad Sandiri Memet, desc=Indonesian politician (born 1969 in Raha)
# Q108902819, name=Wa Ode Nur Zainab, desc=Indonesian politician (born 1972 in Raha)
# Q25466295, name=Safaruddin Datuak Bandaro, desc=politikus Indonesia
# Q109831040, name=Wannofri Samry, desc=sejarawan pers Indonesia
# Q96988733, name=Delmeria Sikumbang, desc=Indonesian politician
# Q108890204, name=Mairion Ando, desc=Indonesian politician (born 1962 in Paninggahan)
# Q108895174, name=Abdul Kadir Makarim, desc=Indonesian politician (born 1947)
# Q108901713, name=Saleh Ramli, desc=Indonesian politician (born 1977 in Ampana)
# Q108895494, name=Suadi D Tagab, desc=Indonesian politician (born 1952 in Hanua)
# Q108895867, name=Siti Hajar Hamid, desc=Indonesian politician (born 1988 in Monsongan)
# Q108889722, name=Said Bakhri, desc=Indonesian politician (born 1979 in Sungai Piring)
# Q64698005, name=Haliadi Sadi, desc=b. in Buton, Sulawesi Tenggara, Oct. 11, 1971; S-2, Universitas Gadjah Mada; presentle, dosen tetap Universitas Tadulako
# Q108902856, name=Lusi Yikwa, desc=Indonesian politician (born 1975 in Mogonik)
# Q108889728, name=Elmansyah Telaumbanua, desc=Indonesian politician (born 1964 in Miga)
# Q108732675, name=Victor Ahn, desc=Member of the Volksraad
# Q111670665, name=Elisabeth Johanna Rijkebüsch, desc=botanical collector (1902 - 1984)
# Q111828240, name=Adolph Hendrik Philip Hoogesteger, desc=recipient of the Honorary Medal for Charitable Assistance
# Q108896092, name=A. Rosnaeni S., desc=Indonesian politician (born 1961 in Kabauw)
# Q107578359, name=Jan Pavel, desc=
# Q108894710, name=Muhammad Ilyas, desc=Indonesian politician (born 1968 in Sampit)
# Q108895446, name=Sariyani, desc=Indonesian politician (born 1962 in Sampit)
# Q108895459, name=Muhammad Gumarang, desc=Indonesian politician (born 1964)
# Q108895486, name=Sugianto Sabran, desc=Indonesian politician (born in Sampit)
# Q108895523, name=Yoyo Arif Ardhani, desc=Indonesian politician (born 1972 in Sampit)
# Q97590730, name=Yayat Y. Biaro, desc=Indonesian politician
# Q108892396, name=Pamriadi, desc=Indonesian politician (born 1977 in Tanggerang)
# Q108893625, name=Nana Mahdiana, desc=Indonesian politician (born 1967 in Tanggerang)
# Q108894917, name=Gusti Bagia Mulyadi, desc=Indonesian politician (born 1950)
# Q108901465, name=Prima Heriyanti, desc=Indonesian politician (born 1987 in Kayuagung)
# Q108895805, name=Jurhum Lantong, desc=Indonesian politician (born 1968 in Motoboi Kecil)
# Q108895667, name=Yohanes Libut, desc=Indonesian politician (born 1955 in Pa Padi)
# Q108902732, name=Andi Basri Jaya, desc=Indonesian politician (born 1968 in Cabenge)
# Q108896451, name=Mukti Baba, desc=Indonesian politician (born 1978 in Wasileo)
# Q108895081, name=Supardi, desc=Indonesian politician (born 1968 in Mendo)
# Q108895415, name=R. Epesus Nyarong, desc=Indonesian politician (born 1959 in Moro Betung)
# Q108895889, name=Marie June Elizabeth Balebu, desc=politisi Indonesia
# Q108890041, name=Indah Kusumawati, desc=Indonesian politician (born 1978 in Sarang Bulan)
# Q108890359, name=Melis Puspasari, desc=Indonesian politician (born 1991 in Air Mesu)
# Q108895917, name=Sri Nurwana Nurdin, desc=Indonesian politician (born 1992 in Kampung Beru)
# Q108553614, name=Ian Falconer, desc=translator and catholic priest (1916-2004)
# Q108890135, name=Erwin Ricardo Silalahi, desc=Indonesian politician (born 1964)
# Q108895413, name=Sukiman, desc=Indonesian politician (born 1968 in Nanga Pak)
# Q108895416, name=Evi Ruliati, desc=Indonesian politician (born 1986 in Sungai Jaga B)
# Q108895336, name=Edy Gunawan, desc=Indonesian politician (born 1979 in Semudun)
# Q87484151, name=黃麗群, desc=Istri Andreas Li
# Q109450510, name=Finna Lutviyanita, desc=politisi Indonesia
# Q108901500, name=Simeon Petrus, desc=Indonesian politician (born 1965 in Hoder)
# Q97590598, name=Honing Sanny, desc=Indonesian politician
# Q108895437, name=Danthe Theodore, desc=Indonesian politician (born 1956 in Nanga Bulik)
# Q108890330, name=Ediwarman Gucci, desc=Indonesian politician (born 1965)
# Q25467234, name=Husnizar Hood, desc=
# Q108895469, name=Christinus Benny, desc=Indonesian politician (born 1969 in Tumbang Lahang)
# Q108902068, name=Flor Suryadarma, desc=Indonesian politician (born 1962 in Betenung)
# Q108895937, name=Debora Bumbungan, desc=Indonesian politician (born 1962 in Lempo)
# Q108890304, name=Samarcondy Nawawi, desc=Indonesian politician (born in Ulak Ketapang)
# Q108895497, name=Kornelis S Matan, desc=Indonesian politician (born 1980 in Tumbang Ponyoi)
# Q108888977, name=Faisal Ridha, desc=Indonesian politician (born 1974 in Dayah Mesjid)
# Q108890852, name=Sugianto Nangolah, desc=Indonesian politician (born 1963 in Desa Kota Gading)
# Q108889983, name=Garnawi, desc=Indonesian politician (born 1967 in Purun)
# Q108890099, name=Mudarwan Yusuf, desc=Indonesian politician (born 1964 in Bintuhan)
# Q108895919, name=Anwar Amin, desc=Indonesian politician (born 1975 in Baru Tancung)
# Q108902708, name=Hijrah S. Lanase, desc=Indonesian politician (born 1979 in Guntarano)
# Q96989441, name=Amir Uskara, desc=Indonesian politician
# Q108895921, name=Asma Semma, desc=Indonesian politician (born 1984 in Sungguminasa)
# Q114073673, name=Sofy Al Mushira Asharunnisa, desc=badminton player
# Q109444532, name=Norman Zainal, desc=Indonesian politician
# Q108081182, name=Siti Iesmaniasita, desc=Indonesian writer
# Q108895399, name=Sumarno, desc=Indonesian politician (born 1962 in Mentunai)
# Q108894265, name=Rania Melani, desc=Indonesian politician (born 1976 in Bedeng Dua)
# Q108895873, name=Abdullah Mahmud Bampe, desc=Indonesian politician (born 1945 in Tosale)
# Q108902882, name=Izak Bahamba, desc=Indonesian politician (born 1955 in Puar)
# Q108730938, name=Cornelis Elize Barre, desc=Civil servant in the Netherlands Indies
# Q108896392, name=Jafet Damamain, desc=Indonesian politician (born 1956 in Wasarili)
# Q20113748, name=Jan Westerveld, desc=mineralogist and economic geologist, University of Amsterdam
# Q96948673, name=Bohdan Z. Stachiw, desc=
# Q108896455, name=Saiful Ahmad, desc=Indonesian politician (born 1974 in Tokaka)
# Q108896458, name=Husni Salim, desc=Indonesian politician (born 1971 in Bibinoi)
# Q108895848, name=Saing, desc=Indonesian politician (born 1974 in Ongka)
# Q108890543, name=Irawan Ronodipuro, desc=Indonesian politician (born 1957 in London)
# Q108896607, name=Regina Sauyai Salamahu, desc=Indonesian politician (born 1954 in Arupi)
# Q108895939, name=Syamsari, desc=Indonesian politician (born 1974)
# Q108889317, name=Hamdan Harahap, desc=Indonesian politician (born 1958 in Siancimun)
# Q108889080, name=Pujowarno, desc=Indonesian politician (born 1955 in Tanjung Kasau)

# %% [markdown]
# ### create list of people name "Bambang" for test

# %%
test_data_name = {qid:name for qid,name in name_dict.items() if qid in ["Q975434", "Q57405", "Q805927"]}
test_data_desc = {qid:desc for qid,desc in desc_dict.items() if qid in ["Q975434", "Q57405", "Q805927"]}
print(test_data_desc)
# Out:
# {'Q57405': 'Presiden ke-6 Republik Indonesia dari 2004 sampai 2014', 'Q975434': 'pesepak bola Indonesia', 'Q805927': 'badminton player'}

# %% [markdown]
# ### Create Knowledge Base

# %%
from spacy.kb import KnowledgeBase
def create_kb(vocab):
    return KnowledgeBase(vocab=vocab, entity_vector_length=96)

kb = create_kb(model.vocab)

# %% [markdown]
# #### add each record to knowledge base by encode its description using built-in vector of nlp model

# %%
vector = model.vocab
print(vector)
# Out:
# <spacy.vocab.Vocab object at 0x000001F1693541F0>

# %%
for id,teks in test_data_desc.items():
    print(teks)
    pred_desc = model(teks)
    print([(tes.text, tes.label_) for tes in pred_desc.ents])
# Out:
# Presiden ke-6 Republik Indonesia dari 2004 sampai 2014
# [('Presiden', 'JOB_TITLE'), ('Indonesia', 'GPE')]
# pesepak bola Indonesia
# [('Indonesia', 'GPE')]
# badminton player
# []

# %%
for qid,desc in test_data_desc.items():
    desc_doc = model(desc)
    print(type(desc_doc))
    print([(tes.text, tes.has_vector, tes.vector_norm) for tes in desc_doc.ents])
    desc_enc = desc_doc.vector
    print(desc_enc)
    kb.add_entity(entity=qid, entity_vector=desc_enc, freq=342)
# Out:
# <class 'spacy.tokens.doc.Doc'>
# [('Presiden', True, 24.466875), ('Indonesia', True, 22.693472)]
# [ 0.75242615 -1.0240536   0.25938946  1.298917    0.5808679  -0.7929794
#  -0.63040495 -0.10847893 -1.0475309   0.6115074  -0.7011555   0.09636406
#  -1.648802    0.9305185   0.70654714 -0.16597208 -1.6405128  -0.16758516
#  -0.51248276 -0.1905116  -0.6443113  -0.07427826  0.9403927  -0.80078924
#   0.04926576  0.8441375  -0.618108    0.9908975  -0.0538023   0.5456103
#   0.02248681 -1.2348497   1.1346684  -1.0934504   0.00873392  0.8128322
#  -0.00238701  0.36538142 -1.0543642   0.6252912   0.2132651   0.36654904
#   0.66815495 -0.55302393  0.37822193  0.16564529 -0.51167506 -1.1713943
#  -1.0999238  -0.5293921   0.9970094   1.3657238  -0.62867385  0.4122885
#   0.9147053  -0.09679216 -0.91339463  0.4513821   0.19641992 -0.3173883
#   0.11974125 -0.05921207 -0.27352542 -2.1573308  -1.5245266   0.73461616
#  -1.393272   -0.25371832 -0.8425559   0.9648364  -0.0079657   0.9440492
#   0.65751916  0.71331644  0.20244043  0.02653944 -0.01578002  0.7653427
#  -0.17125826 -0.28295976 -0.3719205  -0.5917348   0.9019043   1.1019884
#   0.68164957  0.8218397  -0.41431484 -0.4534251  -0.20717725  0.11368563
#  -0.8749016  -0.28271165  2.2358792   0.2982162   0.79333675  0.42425433]
# <class 'spacy.tokens.doc.Doc'>
# [('Indonesia', True, 22.745914)]
# [-9.8936796e-01 -2.1304688e+00  5.1514059e-01  7.4076110e-01
#   2.8067455e+00  2.6343063e-01 -1.3602495e-02 -2.3869615e+00
#  -9.5492744e-01  2.5445488e-01 -1.4958849e+00  1.8665242e-01
#   6.4833754e-01  5.1115549e-01 -6.2009138e-01  1.3007625e+00
#  -4.6448085e-01 -1.6457275e+00 -8.3124572e-01 -8.7947965e-02
#  -1.5085382e+00  7.1553850e-01  1.9756914e+00 -2.8495252e-01
#   1.4959127e+00  1.4097387e-01 -1.4534879e+00  1.0598917e+00
#   6.4514548e-01  3.5330310e-01  1.3909870e+00 -6.2802130e-01
#  -1.4533116e+00 -2.0509608e+00  8.2139246e-02 -8.9955926e-01
#   2.8411070e-02 -1.9747678e+00 -7.9838119e-02  1.5229439e+00
#  -2.4160395e+00 -2.0356257e-01 -1.7370892e+00  1.7727891e+00
#   6.0489720e-01  1.1097993e+00  2.2872026e+00 -1.8415047e+00
#  -2.7790821e+00 -4.1206703e-01  1.0506190e+00  7.3157154e-02
#  -1.6045150e+00  4.2083461e-02  4.3565211e-01 -3.7067533e-01
#   1.5230299e+00 -1.1289126e+00 -7.5527626e-01  9.1906764e-02
#   1.5264376e+00 -7.2708291e-01  6.5130407e-01 -1.3335428e+00
#  -2.5479820e+00 -1.9364445e-01 -9.9873954e-01  1.2706957e+00
#   1.5438963e+00 -6.1726946e-01  2.4290860e-02  1.6520096e+00
#   1.3773661e+00  4.5338395e-01  7.5251883e-01 -3.9018574e-01
#   2.8650990e+00  1.3293636e-01 -3.9780977e-01  5.3132033e-01
#  -3.3294361e-02  7.6656777e-01 -1.6378124e-01  7.4396133e-02
#   9.4985199e-01  1.3425523e+00 -2.5665741e+00  1.1901971e-01
#  -4.2231879e-04  1.3438208e-01 -3.9561710e-01  9.9091667e-01
#   1.9133043e+00 -3.6883664e-01  5.0753951e-01  7.2834796e-01]
# <class 'spacy.tokens.doc.Doc'>
# []
# [ 1.1871462  -0.7717062   1.5981578  -0.07147588 -0.65576434 -2.518527
#  -0.9077156  -2.086031   -0.6444298   0.89777267 -1.0214069   1.7403412
#  -0.15258968  0.5663596  -2.303789    1.1624575   0.6190862  -0.19960898
#   0.80870974 -0.5248352  -0.8443466   0.4766634   4.854214    0.04639168
#   0.22218803  3.240008    0.5512453  -0.8963603  -1.2162309   0.6462772
#   0.9464954  -1.4340024  -2.5635414  -2.5099096  -2.197145   -0.78405476
#   2.09906     0.02924109 -0.8584336   2.5620966  -4.2814307   2.8944378
#   0.2964936   1.4553626  -0.39126593  1.5381814   2.0847383   1.8263179
#   1.0197369  -1.6351123  -0.03995344  0.9905429  -2.4851704  -1.716262
#   0.32850695  1.3765013  -2.6375728  -0.7771362  -0.7117014   0.1153602
#  -0.92879677 -2.57053    -0.53497005 -1.7829509   1.9113995   2.568807
#  -0.64451325  1.5728993  -0.7385321  -1.6625292   1.4959912   0.82193345
#   0.6019542   0.9089129   2.2869906   1.3868419   2.6403623   1.0649028
#  -0.6301954   2.136643   -0.8161501   1.5171556   1.9009674  -0.65582234
#  -0.6868239  -0.8327495  -1.9565418  -1.434641   -0.04418315 -1.2265728
#  -1.4732847   1.1759467   0.15361929 -0.48229647 -0.8414792  -2.544343  ]

# %% [markdown]
# ### add aliases for each QID

# %%
for qid, name in test_data_name.items():
    kb.add_alias(alias=name, entities=[qid], probabilities=[1])

# %%
qids = test_data_name.keys()
probs = [0.3 for qid in qids]
kb.add_alias(alias="Bambang", entities=qids, probabilities=probs)
# Out:
# 4734843956947139246

# %%
print(f"Entities in the KB: {kb.get_entity_strings()}")
print(f"Aliases in the KB: {kb.get_alias_strings()}")
# Out:
# Entities in the KB: ['Q975434', 'Q57405', 'Q805927']
# Aliases in the KB: ['Susilo Bambang Yudhoyono', 'Bambang Suprianto', 'Bambang Pamungkas', 'Bambang']

# %%
print(f"Candidates for SBY: {[c.entity_ for c in kb.get_alias_candidates('Susilo Bambang Yudhoyono')]}")
print(f"Candidates for Bambang: {[c.entity_ for c in kb.get_alias_candidates('Bambang')]}")
# Out:
# Candidates for SBY: ['Q57405']
# Candidates for Bambang: ['Q57405', 'Q975434', 'Q805927']

# %% [markdown]
# ### Save KnowledgeBase

# %%
import os
output_dir = Path.cwd()/"kb_test"
kb.to_disk(output_dir / "my_kb")

# %% [markdown]
# ### Create Training Data for KnowledgeBase

# %%
with open("text.txt") as file:
    training_text = file.readlines()

# %%
import pprint
pprint.pprint(training_text)
# Out:
# ['Bambang merupakan presiden ke-6 indonesia.\n',
#  'Bambang Pamungkas menjadi pemain bola yang diandalkan.\n',
#  'Pertandingan Bambang di thomas cup sangat dinantikan.\n',
#  'Kinerja yang ditunjukan oleh Bambang untuk negara sangat luar biasa.\n',
#  'Bambang atau yang biasa disebut bepe itu menjadi kapten timnas yang '
#  'dipercaya rekan timnya.\n',
#  'Raket yang digunakan oleh Bambang dijual dengan harga yang fantastis.\n',
#  'Pertemuan antara Bambang dengan perdana menteri inggris menghasilkan sebuah '
#  'kolaborasi.\n',
#  'Tendangan yang dilakukan Bambang berhasil mencetok skor untuk indonesia.\n',
#  'Smash yang dilakukan oleh Bambang sangat ditakuti oleh lawan-lawannya.\n',
#  'Bambang yang dulunya seorang jenderal TNI tentunya memiliki kedisiplinan '
#  'yang tinggi.\n',
#  'Bambang sebagai kapten kesulitan untuk membimbing rekan satu timnya di '
#  'lapangan.\n',
#  'Sebagai atlet bulu tangkis, Bambang selalu tekun melatih tekniknya.\n',
#  'Susilo Bambang Yudhoyono merupakan Presiden Indonesia ke-6.\n',
#  'Bambang Pamungkas sempat ikut serta dalam pembuatan film sepak bola.\n',
#  'Bambang Suprianto adalah seorang atlet Bulu tangkis.\n',
#  'Setelah masa jabatan Bambang berakhir sebagai Presiden, kini beliau sering '
#  'melukis.\n',
#  'Bambang kini berperan sebagai manajer tim sepakbola Persija.\n',
#  'Bambang ditunjuk untuk menjadi pelatih timnas bulutangkis putri.\n',
#  'Presiden ke-6 RI Susilo Bambang Yudhoyono (SBY) mengatakan dia mulai melukis '
#  'sejak Mei 2021.\n',
#  'Sang ayah pernah berpartner dengan Bambang Pamungkas di Timnas Indonesia dan '
#  'Persija pada akhir 1990-an dan awal 2000-an.\n',
#  'Bersama Rudy Gunawan, ia sempat mengalahkan Ricky Subagja/Rexy Mainaky yang '
#  'menjadi pasangan ganda putra terbaik dunia dari Indonesia di partai final '
#  'All England 1994.\n',
#  'Susilo Bambang Yudhoyono yang pernah ditugaskan dalam Operasi Seroja di '
#  'Timor-Timur\n',
#  'Bambang dianggap memiliki header bola yang luar biasa, dan memiliki reputasi '
#  'untuk ketajaman di kotak penalti.\n',
#  'Bambang memulai kariernya pada tahun 1990 di Piala Thomas 1990 bersama Rudy '
#  'Gunawan, tetapi dikalahkan oleh Razeef Sidek dan Jalani Sidek dari '
#  'Malaysia.\n',
#  'Bambang kemudian dicatat sebagai presiden terpilih pertama pilihan rakyat, '
#  'dan tampil sebagai Presiden Indonesia keenam setelah dilantik pada 20 '
#  'Oktober 2004.\n',
#  'Bambang juga pernah menjadi pencetak gol terbanyak untuk skuat Indonesia di '
#  'Piala Asia U-19 Grup V.\n',
#  'Bambang bersaing dalam pertandingan Bulu tangkis pada Olimpiade 1996 nomor '
#  'Ganda Pria.\n',
#  'Bambang menjaringkan 24 gol pada musim pertamanya di Liga Indonesia walaupun '
#  'tim yang diwakilinya Persija Jakarta gagal ke babak akhir.\n',
#  'Pada saat pelantikannya pertama kali sebagai presiden, Bambang mengumumkan '
#  'kabinet barunya, yang akan dikenal sebagai Kabinet Indonesia Bersatu yang '
#  'terdiri dari 36 menteri.\n',
#  'Bambang Supriyanto sudah mengambil alih peran Edwin Iriawan dengan '
#  'mendampingi tim Piala Uber Indonesia di Kunshan, China.']

# %%
print(training_text[0][-2])
# Out:
# .

# %%
# train_doc = model(kalimat)
# print(train_doc)
# for tes in train_doc.ents:
#     print(tes.text, tes.label_)
# span = train_doc[0:3]
# print(span)
import re

def get_offset(text, list_ent):
    token_list = []
    for token in list_ent:
        for match in re.finditer(re.escape(token[0]), text):
            token_list.append(
                {
                    "start" : match.start(),
                    "end" : match.end(),
                    "word" : token[0]
                }
            )
    return token_list

def predict_word():
    list_ent_link = []
    for sentence in training_text:
        train_doc = model(sentence)
        list_token = [(ent.text, ent.label_) for ent in train_doc.ents]
        list_offset = get_offset(sentence, list_token)
        list_offset = [(word["start"],word["end"]) for word in list_offset if  word["word"]=="Susilo Bambang Yudhoyono" or word["word"]=="Bambang Pamungkas" or word["word"]=="Bambang Suprianto" or word["word"]=="Bambang"]
        for offset in list_offset:
            links_dict = {" ":1.0}
            list_ent_link.append((sentence, {"links":{offset: links_dict}}))
    return list_ent_link

# %%
list_ent = predict_word()
print(len(list_ent))
for cek in list_ent:
    pprint.pprint(cek)
# Out:
# 23
# ('Bambang merupakan presiden ke-6 indonesia.\n',
#  {'links': {(0, 7): {' ': 1.0}}})
# ('Bambang Pamungkas menjadi pemain bola yang diandalkan.\n',
#  {'links': {(0, 17): {' ': 1.0}}})
# ('Kinerja yang ditunjukan oleh Bambang untuk negara sangat luar biasa.\n',
#  {'links': {(29, 36): {' ': 1.0}}})
# ('Bambang atau yang biasa disebut bepe itu menjadi kapten timnas yang '
#  'dipercaya rekan timnya.\n',
#  {'links': {(0, 7): {' ': 1.0}}})
# ('Raket yang digunakan oleh Bambang dijual dengan harga yang fantastis.\n',
#  {'links': {(26, 33): {' ': 1.0}}})
# ('Pertemuan antara Bambang dengan perdana menteri inggris menghasilkan sebuah '
#  'kolaborasi.\n',
#  {'links': {(17, 24): {' ': 1.0}}})
# ('Tendangan yang dilakukan Bambang berhasil mencetok skor untuk indonesia.\n',
#  {'links': {(25, 32): {' ': 1.0}}})
# ('Smash yang dilakukan oleh Bambang sangat ditakuti oleh lawan-lawannya.\n',
#  {'links': {(26, 33): {' ': 1.0}}})
# ('Bambang yang dulunya seorang jenderal TNI tentunya memiliki kedisiplinan '
#  'yang tinggi.\n',
#  {'links': {(0, 7): {' ': 1.0}}})
# ('Bambang sebagai kapten kesulitan untuk membimbing rekan satu timnya di '
#  'lapangan.\n',
#  {'links': {(0, 7): {' ': 1.0}}})
# ('Sebagai atlet bulu tangkis, Bambang selalu tekun melatih tekniknya.\n',
#  {'links': {(28, 35): {' ': 1.0}}})
# ('Susilo Bambang Yudhoyono merupakan Presiden Indonesia ke-6.\n',
#  {'links': {(0, 24): {' ': 1.0}}})
# ('Bambang Pamungkas sempat ikut serta dalam pembuatan film sepak bola.\n',
#  {'links': {(0, 17): {' ': 1.0}}})
# ('Bambang Suprianto adalah seorang atlet Bulu tangkis.\n',
#  {'links': {(0, 17): {' ': 1.0}}})
# ('Setelah masa jabatan Bambang berakhir sebagai Presiden, kini beliau sering '
#  'melukis.\n',
#  {'links': {(21, 28): {' ': 1.0}}})
# ('Bambang kini berperan sebagai manajer tim sepakbola Persija.\n',
#  {'links': {(0, 7): {' ': 1.0}}})
# ('Sang ayah pernah berpartner dengan Bambang Pamungkas di Timnas Indonesia dan '
#  'Persija pada akhir 1990-an dan awal 2000-an.\n',
#  {'links': {(35, 52): {' ': 1.0}}})
# ('Susilo Bambang Yudhoyono yang pernah ditugaskan dalam Operasi Seroja di '
#  'Timor-Timur\n',
#  {'links': {(0, 24): {' ': 1.0}}})
# ('Bambang dianggap memiliki header bola yang luar biasa, dan memiliki reputasi '
#  'untuk ketajaman di kotak penalti.\n',
#  {'links': {(0, 7): {' ': 1.0}}})
# ('Bambang memulai kariernya pada tahun 1990 di Piala Thomas 1990 bersama Rudy '
#  'Gunawan, tetapi dikalahkan oleh Razeef Sidek dan Jalani Sidek dari '
#  'Malaysia.\n',
#  {'links': {(0, 7): {' ': 1.0}}})
# ('Bambang juga pernah menjadi pencetak gol terbanyak untuk skuat Indonesia di '
#  'Piala Asia U-19 Grup V.\n',
#  {'links': {(0, 7): {' ': 1.0}}})
# ('Bambang bersaing dalam pertandingan Bulu tangkis pada Olimpiade 1996 nomor '
#  'Ganda Pria.\n',
#  {'links': {(0, 7): {' ': 1.0}}})
# ('Pada saat pelantikannya pertama kali sebagai presiden, Bambang mengumumkan '
#  'kabinet barunya, yang akan dikenal sebagai Kabinet Indonesia Bersatu yang '
#  'terdiri dari 36 menteri.\n',
#  {'links': {(55, 62): {' ': 1.0}}})

# %%
print(test_data_name)
# Out:
# {'Q57405': 'Susilo Bambang Yudhoyono', 'Q975434': 'Bambang Pamungkas', 'Q805927': 'Bambang Suprianto'}

# %%
def insert_QID():
    list_ent[0][1]["links"][(0, 7)]["Q57405"] = list_ent[0][1]["links"][(0, 7)][" "]
    del list_ent[0][1]["links"][(0, 7)][" "]

    list_ent[1][1]["links"][(0, 17)]["Q975434"] = list_ent[1][1]["links"][(0, 17)][" "]
    del list_ent[1][1]["links"][(0, 17)][" "]

    list_ent[2][1]["links"][(29, 36)]["Q57405"] = list_ent[2][1]["links"][(29, 36)][" "]
    del list_ent[2][1]["links"][(29, 36)][" "]

    list_ent[3][1]["links"][(0, 7)]["Q975434"] = list_ent[3][1]["links"][(0, 7)][" "]
    del list_ent[3][1]["links"][(0, 7)][" "]

    list_ent[4][1]["links"][(26, 33)]["Q805927"] = list_ent[4][1]["links"][(26, 33)][" "]
    del list_ent[4][1]["links"][(26, 33)][" "]

    list_ent[5][1]["links"][(17, 24)]["Q57405"] = list_ent[5][1]["links"][(17, 24)][" "]
    del list_ent[5][1]["links"][(17, 24)][" "]

    list_ent[6][1]["links"][(25, 32)]["Q975434"] = list_ent[6][1]["links"][(25, 32)][" "]
    del list_ent[6][1]["links"][(25, 32)][" "]

    list_ent[7][1]["links"][(26, 33)]["Q805927"] = list_ent[7][1]["links"][(26, 33)][" "]
    del list_ent[7][1]["links"][(26, 33)][" "]

    list_ent[8][1]["links"][(0, 7)]["Q57405"] = list_ent[8][1]["links"][(0, 7)][" "]
    del list_ent[8][1]["links"][(0, 7)][" "]

    list_ent[9][1]["links"][(0, 7)]["Q975434"] = list_ent[9][1]["links"][(0, 7)][" "]
    del list_ent[9][1]["links"][(0, 7)][" "]

    list_ent[10][1]["links"][(28, 35)]["Q805927"] = list_ent[10][1]["links"][(28, 35)][" "]
    del list_ent[10][1]["links"][(28, 35)][" "]

    list_ent[11][1]["links"][(0, 24)]["Q57405"] = list_ent[11][1]["links"][(0, 24)][" "]
    del list_ent[11][1]["links"][(0, 24)][" "]

    list_ent[12][1]["links"][(0, 17)]["Q975434"] = list_ent[12][1]["links"][(0, 17)][" "]
    del list_ent[12][1]["links"][(0, 17)][" "]

    list_ent[13][1]["links"][(0, 17)]["Q805927"] = list_ent[13][1]["links"][(0, 17)][" "]
    del list_ent[13][1]["links"][(0, 17)][" "]

    list_ent[14][1]["links"][(21, 28)]["Q57405"] = list_ent[14][1]["links"][(21, 28)][" "]
    del list_ent[14][1]["links"][(21, 28)][" "]

    list_ent[15][1]["links"][(0, 7)]["Q975434"] = list_ent[15][1]["links"][(0, 7)][" "]
    del list_ent[15][1]["links"][(0, 7)][" "]

    list_ent[16][1]["links"][(35, 52)]["Q975434"] = list_ent[16][1]["links"][(35, 52)][" "]
    del list_ent[16][1]["links"][(35, 52)][" "]

    list_ent[17][1]["links"][(0, 24)]["Q57405"] = list_ent[17][1]["links"][(0, 24)][" "]
    del list_ent[17][1]["links"][(0, 24)][" "]

    list_ent[18][1]["links"][(0, 7)]["Q975434"] = list_ent[18][1]["links"][(0, 7)][" "]
    del list_ent[18][1]["links"][(0, 7)][" "]

    list_ent[19][1]["links"][(0, 7)]["Q805927"] = list_ent[19][1]["links"][(0, 7)][" "]
    del list_ent[19][1]["links"][(0, 7)][" "]

    list_ent[20][1]["links"][(0, 7)]["Q975434"] = list_ent[20][1]["links"][(0, 7)][" "]
    del list_ent[20][1]["links"][(0, 7)][" "]

    list_ent[21][1]["links"][(0, 7)]["Q805927"] = list_ent[21][1]["links"][(0, 7)][" "]
    del list_ent[21][1]["links"][(0, 7)][" "]

    list_ent[22][1]["links"][(55, 62)]["Q57405"] = list_ent[22][1]["links"][(55, 62)][" "]
    del list_ent[22][1]["links"][(55, 62)][" "]
    
    return list_ent

# %%
if " " in list_ent[0][1]["links"][(0, 7)]:
    new_ent = insert_QID()

# %%
print(new_ent[0])
# Out:
# ('Bambang merupakan presiden ke-6 indonesia.\n', {'links': {(0, 7): {'Q57405': 1.0}}})

# %% [markdown]
# ### Check proportion

# %%
gold_ids = []
for text, annot in new_ent:
    for span, links_dict in annot["links"].items():
        for link, value in links_dict.items():
            if value:
                gold_ids.append(link)
                
from collections import Counter
print(Counter(gold_ids))
# Out:
# Counter({'Q975434': 9, 'Q57405': 8, 'Q805927': 6})

# %%
import random

train_dataset = []
test_dataset = []

for QID in qids:
    indices = [i for i,j in enumerate(gold_ids) if j==QID]
    if QID == "Q975434":
        train_dataset.extend(new_ent[index] for index in indices[0:7])
        test_dataset.extend(new_ent[index] for index in indices[7:9])
    elif QID == "Q57405":
        train_dataset.extend(new_ent[index] for index in indices[0:6])
        test_dataset.extend(new_ent[index] for index in indices[6:8])
    elif QID == "Q805927":
        train_dataset.extend(new_ent[index] for index in indices[0:5])
        test_dataset.extend(new_ent[index] for index in indices[5:6])
        
random.shuffle(train_dataset)
random.shuffle(test_dataset)

# %%
TRAIN_DOC = []
for text, annotation in train_dataset:
    doc = model(text)
    TRAIN_DOC.append((doc,annotation))

# %%
entity_linker = model.add_pipe("entity_linker")
entity_linker.set_kb(create_kb)
# model.add_pipe("entity_linker", last=True)
# entity_linker.set_kb(create_kb)

# %%
from spacy.util import minibatch, compounding

other_pipes = [pipe for pipe in model.pipe_names if pipe!="entity_linker"]
with model.disable_pipes(*other_pipes):
    optimizer = model.begin_training()
    for itn in range(500):
        random.shufle(TRAIN_DOC)
        batches = minibatch(TRAIN_DOC, size=compounding(4.0, 32.0, 1.001))
        losses = {}
        for batch in batches:
            texts, annotations = zip(*batch)
            nlp.update(
                texts,
                annotations,
                drop=0.2,
                losses=losses,
                sgd=optimizer,
            )
        if itn % 50 == 0:
            print(itn, "Losses", losses)
print(itn, "Losses", losses)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 4>()
#       3 other_pipes = [pipe for pipe in model.pipe_names if pipe!="entity_linker"]
#       4 with model.disable_pipes(*other_pipes):
# ----> 5     optimizer = model.begin_training()
#       6     for itn in range(500):
#       7         random.shufle(TRAIN_DOC)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\language.py:1258, in Language.begin_training(self, get_examples, sgd)
#    1251 def begin_training(
#    1252     self,
#    1253     get_examples: Optional[Callable[[], Iterable[Example]]] = None,
#    1254     *,
#    1255     sgd: Optional[Optimizer] = None,
#    1256 ) -> Optimizer:
#    1257     warnings.warn(Warnings.W089, DeprecationWarning)
# -> 1258     return self.initialize(get_examples, sgd=sgd)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\language.py:1317, in Language.initialize(self, get_examples, sgd)
#    1313         p_settings = I["components"].get(name, {})
#    1314         p_settings = validate_init_settings(
#    1315             proc.initialize, p_settings, section="components", name=name
#    1316         )
# -> 1317         proc.initialize(get_examples, nlp=self, **p_settings)
#    1318 pretrain_cfg = config.get("pretraining")
#    1319 if pretrain_cfg:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\pipeline\entity_linker.py:253, in EntityLinker.initialize(self, get_examples, nlp, kb_loader)
#     251 if kb_loader is not None:
#     252     self.set_kb(kb_loader)
# --> 253 self.validate_kb()
#     254 nO = self.kb.entity_vector_length
#     255 doc_sample = []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\pipeline\entity_linker.py:229, in EntityLinker.validate_kb(self)
#     227     raise ValueError(Errors.E1018.format(name=self.name))
#     228 if len(self.kb) == 0:
# --> 229     raise ValueError(Errors.E139.format(name=self.name))
#
# ValueError: [E139] Knowledge base for component 'entity_linker' is empty. Use the methods `kb.add_entity` and `kb.add_alias` to add entries.
